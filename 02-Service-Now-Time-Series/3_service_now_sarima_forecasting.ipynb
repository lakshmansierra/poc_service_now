# %% [markdown]
# # sarima Forecasting

# %% [markdown]
# ## Importing the libraries

# %%
import os
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Importing the dataset

# %%
# pyspark_df = spark.table("sd_bdc_demo.sarima_time_series_forecasting.2_am_workday_historic_time_series_updated_data")
# pyspark_df.display()
# df = pyspark_df.toPandas()

# %%
df = pd.read_csv("2_service_now_historic_time_series_updated_data/2_service_now_historic_time_series_updated_data.csv")

# %%
print(df.head())
# Out:
#    Asset_Number Incident_Date  Gap_Days
# 0        100080    2021-04-09       3.0
# 1        100080    2021-04-10       0.0
# 2        100080    2021-04-11       0.0
# 3        100080    2021-04-12       1.0
# 4        100080    2021-04-13       2.0

# %%
print(df.columns)
# Out:
# Index(['Asset_Number', 'Incident_Date', 'Gap_Days'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Asset_Number       int64
# Incident_Date     object
# Gap_Days         float64
# dtype: object

# %%
df['Incident_Date'] = pd.to_datetime(df['Incident_Date'])

# %%
print(df.dtypes)
# Out:
# Asset_Number              int64
# Incident_Date    datetime64[ns]
# Gap_Days                float64
# dtype: object

# %%
print(df.shape)
# Out:
# (121472, 3)

# %%
print(df['Incident_Date'])
# Out:
# 0        2021-04-09
# 1        2021-04-10
# 2        2021-04-11
# 3        2021-04-12
# 4        2021-04-13
#             ...
# 121467   2024-04-14
# 121468   2024-04-15
# 121469   2024-04-16
# 121470   2024-04-17
# 121471   2024-04-18
# Name: Incident_Date, Length: 121472, dtype: datetime64[ns]

# %% [markdown]
# ### Drop null rows

# %%
df = df.dropna()

# %%
print(df.shape)
# Out:
# (121361, 3)

# %% [markdown]
# ## Different Data Frame For Individual assets

# %%
unique_assets = df['Asset_Number'].unique()
print(unique_assets)
# Out:
# [100080 100081 300006 300007 300008 300009 300010 300011 300012 300013
#  300014 300015 300016 300017 300018 300019 300020 300021 300022 300023
#  300024 300025 300026 300027 300028 300029 300030 300031 300032 300033
#  300034 300035 300036 300037 300038 300039 600053 600054 600055 600056
#  600057 600058 600059 600060 600061 600062 600063 600064 600065 600066
#  600067 600068 600069 600070 600071 600072 600073 600074 600075 600076
#  600077 600078 600079 600080 600081 600082 600083 600084 600085 600086
#  600087 600088 600089 600090 600091 600092 600093 600094 600095 600096
#  600097 600098 600099 600100 600101 600102 600103 600104 600105 600106
#  600107 600108 600109 600110 600111 600112 600113 600114 600115 600116
#  600117 600118 600119 600120 600121 600122 600123 600124 600125 600126
#  600127]

# %%
asset_dfs = {}

for asset_id in unique_assets:
    asset_df = df[df['Asset_Number'] == asset_id]

    asset_dfs[asset_id] = asset_df

# %%
individual_asset = asset_dfs[100080]
print(individual_asset)
# Out:
#       Asset_Number Incident_Date  Gap_Days
# 0           100080    2021-04-09       3.0
# 1           100080    2021-04-10       0.0
# 2           100080    2021-04-11       0.0
# 3           100080    2021-04-12       1.0
# 4           100080    2021-04-13       2.0
# ...            ...           ...       ...
# 1091        100080    2024-04-04       3.0
# 1092        100080    2024-04-05       0.0
# 1093        100080    2024-04-06       0.0
# 1094        100080    2024-04-07       2.0
# 1095        100080    2024-04-08       0.0
#
# [1096 rows x 3 columns]

# %%
print(individual_asset.shape)
# Out:
# (1096, 3)

# %% [markdown]
# ## Seasonal Decompose for individual asset

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp = seasonal_decompose(individual_asset['Gap_Days'], model='additive', period=365).plot()

# %% [markdown]
# ### Individual asset Plot

# %%
sns.set(style="whitegrid") 

plt.figure(figsize=(12, 6))
sns.lineplot(data=individual_asset, x='Incident_Date', y='Gap_Days', label='Gap_Days', color='blue')

plt.xlabel('Incident_Date')
plt.ylabel('Gap_Days')
plt.title('Incident_Date VS Gap_Days')

plt.show()

# %% [markdown]
# ## Resampling for individual asset to detect trends

# %%
# Set the date column as the index
individual_asset_date_index_df = individual_asset.set_index('Incident_Date')

individual_asset_date_index_df_resampled = individual_asset_date_index_df.resample('W').mean(numeric_only=True) 

sns.set(style="whitegrid") 

plt.figure(figsize=(12, 6))  
sns.lineplot(data=individual_asset_date_index_df_resampled, x=individual_asset_date_index_df_resampled.index, y='Gap_Days', label='Month Wise gap days', color='blue')

plt.xlabel('Incident_Date (Monthly)')
plt.ylabel('Gap_Days')
plt.title('Monthly Resampling Gap_Days Over Time')

plt.show()

# %% [markdown]
# ## Detecting Individual asset's Seasonality with Auto Correlation

# %%
from statsmodels.graphics.tsaplots import plot_acf

plt.figure(figsize=(12, 6))
plot_acf(individual_asset_date_index_df['Gap_Days'], lags=40) 
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Autocorrelation Function (ACF) Plot')
plt.show()

# %% [markdown]
# ## Forecasting with SARIMAX But without exogenous variable

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
import pandas as pd

def forecast_sarima(asset_df, steps=30):
    asset_df = asset_df.copy()
    asset_df['Incident_Date'] = pd.to_datetime(asset_df['Incident_Date'])
    asset_df = asset_df.sort_values('Incident_Date').set_index('Incident_Date')
    y = asset_df['Gap_Days']

    train = y.iloc[:-steps]
    test = y.iloc[-steps:]

    model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(0, 0, 0, 0), 
                    enforce_stationarity=False, enforce_invertibility=False)
    model_fit = model.fit(disp=False)

    forecast = model_fit.forecast(steps=steps)

    # Compute residuals on training data
    residuals = model_fit.resid
    residuals_df = residuals.reset_index()
    residuals_df.columns = ['Incident_Date', 'residual_value']

    # Metrics
    aic = model_fit.aic
    rmse = np.sqrt(mean_squared_error(test, forecast))

    # Compute MAPE only for incident days (non-zero test values)
    mask = test > 0
    if mask.sum() > 0:
        mape = mean_absolute_percentage_error(test[mask], forecast[mask])
    else:
        mape = np.nan  # No incidents in test set, can't compute MAPE

    return forecast, {
        'AIC': aic,
        'MAPE': mape,
        'RMSE': rmse,
        'ARIMA_order': model_fit.model_orders,
        'residuals': residuals_df
    }

# %%
asset_forecasts = {}
asset_metrics = {}
all_residuals = []

for asset_id, asset_df in asset_dfs.items():
    try:
        forecast, metrics = forecast_sarima(asset_df)
        asset_forecasts[asset_id] = forecast
        asset_metrics[asset_id] = metrics

        # Add residuals to the master list
        residual_df = metrics['residuals'].copy()
        residual_df['Asset_Number'] = asset_id
        all_residuals.append(residual_df)

    except Exception as e:
        print(f"Failed for Asset {asset_id}: {e}")
# Out:
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\LakshmanNavaneethakr\Downloads\lakshmansierra-git\poc_service_now\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
print(type(asset_forecasts))
# Out:
# <class 'dict'>

# %%
print(asset_forecasts.items())
# Out:
# dict_items([(np.int64(100080), 2024-03-10    1.137740
# 2024-03-11    0.982678
# 2024-03-12    1.003812
# 2024-03-13    1.000931
# 2024-03-14    1.001324
# 2024-03-15    1.001270
# 2024-03-16    1.001278
# 2024-03-17    1.001277
# 2024-03-18    1.001277
# 2024-03-19    1.001277
# 2024-03-20    1.001277
# 2024-03-21    1.001277
# 2024-03-22    1.001277
# 2024-03-23    1.001277
# 2024-03-24    1.001277
# 2024-03-25    1.001277
# 2024-03-26    1.001277
# 2024-03-27    1.001277
# 2024-03-28    1.001277
# 2024-03-29    1.001277
# 2024-03-30    1.001277
# 2024-03-31    1.001277
# 2024-04-01    1.001277
# 2024-04-02    1.001277
# 2024-04-03    1.001277
# 2024-04-04    1.001277
# 2024-04-05    1.001277
# 2024-04-06    1.001277
# 2024-04-07    1.001277
# 2024-04-08    1.001277
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(100081), 2024-03-18    1.143354
# 2024-03-19    0.980831
# 2024-03-20    1.003933
# 2024-03-21    1.000649
# 2024-03-22    1.001116
# 2024-03-23    1.001050
# 2024-03-24    1.001059
# 2024-03-25    1.001058
# 2024-03-26    1.001058
# 2024-03-27    1.001058
# 2024-03-28    1.001058
# 2024-03-29    1.001058
# 2024-03-30    1.001058
# 2024-03-31    1.001058
# 2024-04-01    1.001058
# 2024-04-02    1.001058
# 2024-04-03    1.001058
# 2024-04-04    1.001058
# 2024-04-05    1.001058
# 2024-04-06    1.001058
# 2024-04-07    1.001058
# 2024-04-08    1.001058
# 2024-04-09    1.001058
# 2024-04-10    1.001058
# 2024-04-11    1.001058
# 2024-04-12    1.001058
# 2024-04-13    1.001058
# 2024-04-14    1.001058
# 2024-04-15    1.001058
# 2024-04-16    1.001058
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300006), 2024-03-11    1.149063
# 2024-03-12    0.982876
# 2024-03-13    1.006911
# 2024-03-14    1.003435
# 2024-03-15    1.003938
# 2024-03-16    1.003865
# 2024-03-17    1.003876
# 2024-03-18    1.003874
# 2024-03-19    1.003875
# 2024-03-20    1.003875
# 2024-03-21    1.003875
# 2024-03-22    1.003875
# 2024-03-23    1.003875
# 2024-03-24    1.003875
# 2024-03-25    1.003875
# 2024-03-26    1.003875
# 2024-03-27    1.003875
# 2024-03-28    1.003875
# 2024-03-29    1.003875
# 2024-03-30    1.003875
# 2024-03-31    1.003875
# 2024-04-01    1.003875
# 2024-04-02    1.003875
# 2024-04-03    1.003875
# 2024-04-04    1.003875
# 2024-04-05    1.003875
# 2024-04-06    1.003875
# 2024-04-07    1.003875
# 2024-04-08    1.003875
# 2024-04-09    1.003875
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300007), 2024-03-06    1.148334
# 2024-03-07    0.976002
# 2024-03-08    1.001864
# 2024-03-09    0.997983
# 2024-03-10    0.998566
# 2024-03-11    0.998478
# 2024-03-12    0.998491
# 2024-03-13    0.998489
# 2024-03-14    0.998490
# 2024-03-15    0.998490
# 2024-03-16    0.998490
# 2024-03-17    0.998490
# 2024-03-18    0.998490
# 2024-03-19    0.998490
# 2024-03-20    0.998490
# 2024-03-21    0.998490
# 2024-03-22    0.998490
# 2024-03-23    0.998490
# 2024-03-24    0.998490
# 2024-03-25    0.998490
# 2024-03-26    0.998490
# 2024-03-27    0.998490
# 2024-03-28    0.998490
# 2024-03-29    0.998490
# 2024-03-30    0.998490
# 2024-03-31    0.998490
# 2024-04-01    0.998490
# 2024-04-02    0.998490
# 2024-04-03    0.998490
# 2024-04-04    0.998490
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300008), 2024-03-12    0.998122
# 2024-03-13    0.998391
# 2024-03-14    0.998352
# 2024-03-15    0.998358
# 2024-03-16    0.998357
# 2024-03-17    0.998357
# 2024-03-18    0.998357
# 2024-03-19    0.998357
# 2024-03-20    0.998357
# 2024-03-21    0.998357
# 2024-03-22    0.998357
# 2024-03-23    0.998357
# 2024-03-24    0.998357
# 2024-03-25    0.998357
# 2024-03-26    0.998357
# 2024-03-27    0.998357
# 2024-03-28    0.998357
# 2024-03-29    0.998357
# 2024-03-30    0.998357
# 2024-03-31    0.998357
# 2024-04-01    0.998357
# 2024-04-02    0.998357
# 2024-04-03    0.998357
# 2024-04-04    0.998357
# 2024-04-05    0.998357
# 2024-04-06    0.998357
# 2024-04-07    0.998357
# 2024-04-08    0.998357
# 2024-04-09    0.998357
# 2024-04-10    0.998357
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300009), 2024-03-16    1.145364
# 2024-03-17    0.979025
# 2024-03-18    1.003182
# 2024-03-19    0.999674
# 2024-03-20    1.000184
# 2024-03-21    1.000110
# 2024-03-22    1.000120
# 2024-03-23    1.000119
# 2024-03-24    1.000119
# 2024-03-25    1.000119
# 2024-03-26    1.000119
# 2024-03-27    1.000119
# 2024-03-28    1.000119
# 2024-03-29    1.000119
# 2024-03-30    1.000119
# 2024-03-31    1.000119
# 2024-04-01    1.000119
# 2024-04-02    1.000119
# 2024-04-03    1.000119
# 2024-04-04    1.000119
# 2024-04-05    1.000119
# 2024-04-06    1.000119
# 2024-04-07    1.000119
# 2024-04-08    1.000119
# 2024-04-09    1.000119
# 2024-04-10    1.000119
# 2024-04-11    1.000119
# 2024-04-12    1.000119
# 2024-04-13    1.000119
# 2024-04-14    1.000119
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300010), 2024-03-04    1.148118
# 2024-03-05    0.963128
# 2024-03-06    0.992935
# 2024-03-07    0.988132
# 2024-03-08    0.988906
# 2024-03-09    0.988781
# 2024-03-10    0.988801
# 2024-03-11    0.988798
# 2024-03-12    0.988799
# 2024-03-13    0.988798
# 2024-03-14    0.988798
# 2024-03-15    0.988798
# 2024-03-16    0.988798
# 2024-03-17    0.988798
# 2024-03-18    0.988798
# 2024-03-19    0.988798
# 2024-03-20    0.988798
# 2024-03-21    0.988798
# 2024-03-22    0.988798
# 2024-03-23    0.988798
# 2024-03-24    0.988798
# 2024-03-25    0.988798
# 2024-03-26    0.988798
# 2024-03-27    0.988798
# 2024-03-28    0.988798
# 2024-03-29    0.988798
# 2024-03-30    0.988798
# 2024-03-31    0.988798
# 2024-04-01    0.988798
# 2024-04-02    0.988798
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300011), 2024-03-05    1.174601
# 2024-03-06    0.972293
# 2024-03-07    1.007138
# 2024-03-08    1.001136
# 2024-03-09    1.002170
# 2024-03-10    1.001992
# 2024-03-11    1.002022
# 2024-03-12    1.002017
# 2024-03-13    1.002018
# 2024-03-14    1.002018
# 2024-03-15    1.002018
# 2024-03-16    1.002018
# 2024-03-17    1.002018
# 2024-03-18    1.002018
# 2024-03-19    1.002018
# 2024-03-20    1.002018
# 2024-03-21    1.002018
# 2024-03-22    1.002018
# 2024-03-23    1.002018
# 2024-03-24    1.002018
# 2024-03-25    1.002018
# 2024-03-26    1.002018
# 2024-03-27    1.002018
# 2024-03-28    1.002018
# 2024-03-29    1.002018
# 2024-03-30    1.002018
# 2024-03-31    1.002018
# 2024-04-01    1.002018
# 2024-04-02    1.002018
# 2024-04-03    1.002018
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300012), 2024-03-18    1.170253
# 2024-03-19    0.972672
# 2024-03-20    1.006031
# 2024-03-21    1.000399
# 2024-03-22    1.001350
# 2024-03-23    1.001189
# 2024-03-24    1.001216
# 2024-03-25    1.001212
# 2024-03-26    1.001213
# 2024-03-27    1.001212
# 2024-03-28    1.001213
# 2024-03-29    1.001213
# 2024-03-30    1.001213
# 2024-03-31    1.001213
# 2024-04-01    1.001213
# 2024-04-02    1.001213
# 2024-04-03    1.001213
# 2024-04-04    1.001213
# 2024-04-05    1.001213
# 2024-04-06    1.001213
# 2024-04-07    1.001213
# 2024-04-08    1.001213
# 2024-04-09    1.001213
# 2024-04-10    1.001213
# 2024-04-11    1.001213
# 2024-04-12    1.001213
# 2024-04-13    1.001213
# 2024-04-14    1.001213
# 2024-04-15    1.001213
# 2024-04-16    1.001213
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300013), 2024-03-13    0.319644
# 2024-03-14    1.092577
# 2024-03-15    0.987403
# 2024-03-16    1.001714
# 2024-03-17    0.999767
# 2024-03-18    1.000032
# 2024-03-19    0.999996
# 2024-03-20    1.000001
# 2024-03-21    1.000000
# 2024-03-22    1.000000
# 2024-03-23    1.000000
# 2024-03-24    1.000000
# 2024-03-25    1.000000
# 2024-03-26    1.000000
# 2024-03-27    1.000000
# 2024-03-28    1.000000
# 2024-03-29    1.000000
# 2024-03-30    1.000000
# 2024-03-31    1.000000
# 2024-04-01    1.000000
# 2024-04-02    1.000000
# 2024-04-03    1.000000
# 2024-04-04    1.000000
# 2024-04-05    1.000000
# 2024-04-06    1.000000
# 2024-04-07    1.000000
# 2024-04-08    1.000000
# 2024-04-09    1.000000
# 2024-04-10    1.000000
# 2024-04-11    1.000000
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300014), 2024-03-10    0.686971
# 2024-03-11    1.047902
# 2024-03-12    0.991581
# 2024-03-13    1.000369
# 2024-03-14    0.998998
# 2024-03-15    0.999212
# 2024-03-16    0.999179
# 2024-03-17    0.999184
# 2024-03-18    0.999183
# 2024-03-19    0.999183
# 2024-03-20    0.999183
# 2024-03-21    0.999183
# 2024-03-22    0.999183
# 2024-03-23    0.999183
# 2024-03-24    0.999183
# 2024-03-25    0.999183
# 2024-03-26    0.999183
# 2024-03-27    0.999183
# 2024-03-28    0.999183
# 2024-03-29    0.999183
# 2024-03-30    0.999183
# 2024-03-31    0.999183
# 2024-04-01    0.999183
# 2024-04-02    0.999183
# 2024-04-03    0.999183
# 2024-04-04    0.999183
# 2024-04-05    0.999183
# 2024-04-06    0.999183
# 2024-04-07    0.999183
# 2024-04-08    0.999183
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300015), 2024-03-18    1.153812
# 2024-03-19    0.975586
# 2024-03-20    1.003116
# 2024-03-21    0.998864
# 2024-03-22    0.999520
# 2024-03-23    0.999419
# 2024-03-24    0.999435
# 2024-03-25    0.999432
# 2024-03-26    0.999433
# 2024-03-27    0.999433
# 2024-03-28    0.999433
# 2024-03-29    0.999433
# 2024-03-30    0.999433
# 2024-03-31    0.999433
# 2024-04-01    0.999433
# 2024-04-02    0.999433
# 2024-04-03    0.999433
# 2024-04-04    0.999433
# 2024-04-05    0.999433
# 2024-04-06    0.999433
# 2024-04-07    0.999433
# 2024-04-08    0.999433
# 2024-04-09    0.999433
# 2024-04-10    0.999433
# 2024-04-11    0.999433
# 2024-04-12    0.999433
# 2024-04-13    0.999433
# 2024-04-14    0.999433
# 2024-04-15    0.999433
# 2024-04-16    0.999433
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300016), 2024-03-19    0.386069
# 2024-03-20    1.095311
# 2024-03-21    0.986288
# 2024-03-22    1.003047
# 2024-03-23    1.000471
# 2024-03-24    1.000867
# 2024-03-25    1.000806
# 2024-03-26    1.000815
# 2024-03-27    1.000814
# 2024-03-28    1.000814
# 2024-03-29    1.000814
# 2024-03-30    1.000814
# 2024-03-31    1.000814
# 2024-04-01    1.000814
# 2024-04-02    1.000814
# 2024-04-03    1.000814
# 2024-04-04    1.000814
# 2024-04-05    1.000814
# 2024-04-06    1.000814
# 2024-04-07    1.000814
# 2024-04-08    1.000814
# 2024-04-09    1.000814
# 2024-04-10    1.000814
# 2024-04-11    1.000814
# 2024-04-12    1.000814
# 2024-04-13    1.000814
# 2024-04-14    1.000814
# 2024-04-15    1.000814
# 2024-04-16    1.000814
# 2024-04-17    1.000814
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300017), 2024-03-18    1.155545
# 2024-03-19    0.977397
# 2024-03-20    1.004862
# 2024-03-21    1.000628
# 2024-03-22    1.001280
# 2024-03-23    1.001180
# 2024-03-24    1.001195
# 2024-03-25    1.001193
# 2024-03-26    1.001193
# 2024-03-27    1.001193
# 2024-03-28    1.001193
# 2024-03-29    1.001193
# 2024-03-30    1.001193
# 2024-03-31    1.001193
# 2024-04-01    1.001193
# 2024-04-02    1.001193
# 2024-04-03    1.001193
# 2024-04-04    1.001193
# 2024-04-05    1.001193
# 2024-04-06    1.001193
# 2024-04-07    1.001193
# 2024-04-08    1.001193
# 2024-04-09    1.001193
# 2024-04-10    1.001193
# 2024-04-11    1.001193
# 2024-04-12    1.001193
# 2024-04-13    1.001193
# 2024-04-14    1.001193
# 2024-04-15    1.001193
# 2024-04-16    1.001193
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300018), 2024-03-06    0.555287
# 2024-03-07    1.069164
# 2024-03-08    0.992504
# 2024-03-09    1.003940
# 2024-03-10    1.002234
# 2024-03-11    1.002489
# 2024-03-12    1.002451
# 2024-03-13    1.002457
# 2024-03-14    1.002456
# 2024-03-15    1.002456
# 2024-03-16    1.002456
# 2024-03-17    1.002456
# 2024-03-18    1.002456
# 2024-03-19    1.002456
# 2024-03-20    1.002456
# 2024-03-21    1.002456
# 2024-03-22    1.002456
# 2024-03-23    1.002456
# 2024-03-24    1.002456
# 2024-03-25    1.002456
# 2024-03-26    1.002456
# 2024-03-27    1.002456
# 2024-03-28    1.002456
# 2024-03-29    1.002456
# 2024-03-30    1.002456
# 2024-03-31    1.002456
# 2024-04-01    1.002456
# 2024-04-02    1.002456
# 2024-04-03    1.002456
# 2024-04-04    1.002456
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300019), 2024-03-19    1.142949
# 2024-03-20    0.972367
# 2024-03-21    0.997826
# 2024-03-22    0.994026
# 2024-03-23    0.994593
# 2024-03-24    0.994509
# 2024-03-25    0.994521
# 2024-03-26    0.994519
# 2024-03-27    0.994520
# 2024-03-28    0.994520
# 2024-03-29    0.994520
# 2024-03-30    0.994520
# 2024-03-31    0.994520
# 2024-04-01    0.994520
# 2024-04-02    0.994520
# 2024-04-03    0.994520
# 2024-04-04    0.994520
# 2024-04-05    0.994520
# 2024-04-06    0.994520
# 2024-04-07    0.994520
# 2024-04-08    0.994520
# 2024-04-09    0.994520
# 2024-04-10    0.994520
# 2024-04-11    0.994520
# 2024-04-12    0.994520
# 2024-04-13    0.994520
# 2024-04-14    0.994520
# 2024-04-15    0.994520
# 2024-04-16    0.994520
# 2024-04-17    0.994520
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300020), 2024-03-09    1.142868
# 2024-03-10    0.976523
# 2024-03-11    1.000734
# 2024-03-12    0.997210
# 2024-03-13    0.997723
# 2024-03-14    0.997649
# 2024-03-15    0.997659
# 2024-03-16    0.997658
# 2024-03-17    0.997658
# 2024-03-18    0.997658
# 2024-03-19    0.997658
# 2024-03-20    0.997658
# 2024-03-21    0.997658
# 2024-03-22    0.997658
# 2024-03-23    0.997658
# 2024-03-24    0.997658
# 2024-03-25    0.997658
# 2024-03-26    0.997658
# 2024-03-27    0.997658
# 2024-03-28    0.997658
# 2024-03-29    0.997658
# 2024-03-30    0.997658
# 2024-03-31    0.997658
# 2024-04-01    0.997658
# 2024-04-02    0.997658
# 2024-04-03    0.997658
# 2024-04-04    0.997658
# 2024-04-05    0.997658
# 2024-04-06    0.997658
# 2024-04-07    0.997658
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300021), 2024-03-16    0.854689
# 2024-03-17    1.016781
# 2024-03-18    0.993841
# 2024-03-19    0.997087
# 2024-03-20    0.996628
# 2024-03-21    0.996693
# 2024-03-22    0.996684
# 2024-03-23    0.996685
# 2024-03-24    0.996685
# 2024-03-25    0.996685
# 2024-03-26    0.996685
# 2024-03-27    0.996685
# 2024-03-28    0.996685
# 2024-03-29    0.996685
# 2024-03-30    0.996685
# 2024-03-31    0.996685
# 2024-04-01    0.996685
# 2024-04-02    0.996685
# 2024-04-03    0.996685
# 2024-04-04    0.996685
# 2024-04-05    0.996685
# 2024-04-06    0.996685
# 2024-04-07    0.996685
# 2024-04-08    0.996685
# 2024-04-09    0.996685
# 2024-04-10    0.996685
# 2024-04-11    0.996685
# 2024-04-12    0.996685
# 2024-04-13    0.996685
# 2024-04-14    0.996685
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300022), 2024-03-15    0.994356
# 2024-03-16    0.995259
# 2024-03-17    0.995114
# 2024-03-18    0.995137
# 2024-03-19    0.995134
# 2024-03-20    0.995134
# 2024-03-21    0.995134
# 2024-03-22    0.995134
# 2024-03-23    0.995134
# 2024-03-24    0.995134
# 2024-03-25    0.995134
# 2024-03-26    0.995134
# 2024-03-27    0.995134
# 2024-03-28    0.995134
# 2024-03-29    0.995134
# 2024-03-30    0.995134
# 2024-03-31    0.995134
# 2024-04-01    0.995134
# 2024-04-02    0.995134
# 2024-04-03    0.995134
# 2024-04-04    0.995134
# 2024-04-05    0.995134
# 2024-04-06    0.995134
# 2024-04-07    0.995134
# 2024-04-08    0.995134
# 2024-04-09    0.995134
# 2024-04-10    0.995134
# 2024-04-11    0.995134
# 2024-04-12    0.995134
# 2024-04-13    0.995134
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300023), 2024-03-09    1.131918
# 2024-03-10    0.985139
# 2024-03-11    1.004172
# 2024-03-12    1.001704
# 2024-03-13    1.002024
# 2024-03-14    1.001983
# 2024-03-15    1.001988
# 2024-03-16    1.001987
# 2024-03-17    1.001988
# 2024-03-18    1.001988
# 2024-03-19    1.001988
# 2024-03-20    1.001988
# 2024-03-21    1.001988
# 2024-03-22    1.001988
# 2024-03-23    1.001988
# 2024-03-24    1.001988
# 2024-03-25    1.001988
# 2024-03-26    1.001988
# 2024-03-27    1.001988
# 2024-03-28    1.001988
# 2024-03-29    1.001988
# 2024-03-30    1.001988
# 2024-03-31    1.001988
# 2024-04-01    1.001988
# 2024-04-02    1.001988
# 2024-04-03    1.001988
# 2024-04-04    1.001988
# 2024-04-05    1.001988
# 2024-04-06    1.001988
# 2024-04-07    1.001988
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300024), 2024-03-13    1.150446
# 2024-03-14    0.976448
# 2024-03-15    1.002764
# 2024-03-16    0.998784
# 2024-03-17    0.999386
# 2024-03-18    0.999295
# 2024-03-19    0.999309
# 2024-03-20    0.999307
# 2024-03-21    0.999307
# 2024-03-22    0.999307
# 2024-03-23    0.999307
# 2024-03-24    0.999307
# 2024-03-25    0.999307
# 2024-03-26    0.999307
# 2024-03-27    0.999307
# 2024-03-28    0.999307
# 2024-03-29    0.999307
# 2024-03-30    0.999307
# 2024-03-31    0.999307
# 2024-04-01    0.999307
# 2024-04-02    0.999307
# 2024-04-03    0.999307
# 2024-04-04    0.999307
# 2024-04-05    0.999307
# 2024-04-06    0.999307
# 2024-04-07    0.999307
# 2024-04-08    0.999307
# 2024-04-09    0.999307
# 2024-04-10    0.999307
# 2024-04-11    0.999307
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300025), 2024-03-12    1.163492
# 2024-03-13    0.970531
# 2024-03-14    1.002533
# 2024-03-15    0.997226
# 2024-03-16    0.998106
# 2024-03-17    0.997960
# 2024-03-18    0.997984
# 2024-03-19    0.997980
# 2024-03-20    0.997981
# 2024-03-21    0.997981
# 2024-03-22    0.997981
# 2024-03-23    0.997981
# 2024-03-24    0.997981
# 2024-03-25    0.997981
# 2024-03-26    0.997981
# 2024-03-27    0.997981
# 2024-03-28    0.997981
# 2024-03-29    0.997981
# 2024-03-30    0.997981
# 2024-03-31    0.997981
# 2024-04-01    0.997981
# 2024-04-02    0.997981
# 2024-04-03    0.997981
# 2024-04-04    0.997981
# 2024-04-05    0.997981
# 2024-04-06    0.997981
# 2024-04-07    0.997981
# 2024-04-08    0.997981
# 2024-04-09    0.997981
# 2024-04-10    0.997981
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300026), 2024-03-12    1.147487
# 2024-03-13    0.981186
# 2024-03-14    1.005287
# 2024-03-15    1.001794
# 2024-03-16    1.002301
# 2024-03-17    1.002227
# 2024-03-18    1.002238
# 2024-03-19    1.002236
# 2024-03-20    1.002237
# 2024-03-21    1.002237
# 2024-03-22    1.002237
# 2024-03-23    1.002237
# 2024-03-24    1.002237
# 2024-03-25    1.002237
# 2024-03-26    1.002237
# 2024-03-27    1.002237
# 2024-03-28    1.002237
# 2024-03-29    1.002237
# 2024-03-30    1.002237
# 2024-03-31    1.002237
# 2024-04-01    1.002237
# 2024-04-02    1.002237
# 2024-04-03    1.002237
# 2024-04-04    1.002237
# 2024-04-05    1.002237
# 2024-04-06    1.002237
# 2024-04-07    1.002237
# 2024-04-08    1.002237
# 2024-04-09    1.002237
# 2024-04-10    1.002237
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300027), 2024-03-19    0.077786
# 2024-03-20    1.146084
# 2024-03-21    0.981214
# 2024-03-22    1.006659
# 2024-03-23    1.002732
# 2024-03-24    1.003338
# 2024-03-25    1.003244
# 2024-03-26    1.003259
# 2024-03-27    1.003257
# 2024-03-28    1.003257
# 2024-03-29    1.003257
# 2024-03-30    1.003257
# 2024-03-31    1.003257
# 2024-04-01    1.003257
# 2024-04-02    1.003257
# 2024-04-03    1.003257
# 2024-04-04    1.003257
# 2024-04-05    1.003257
# 2024-04-06    1.003257
# 2024-04-07    1.003257
# 2024-04-08    1.003257
# 2024-04-09    1.003257
# 2024-04-10    1.003257
# 2024-04-11    1.003257
# 2024-04-12    1.003257
# 2024-04-13    1.003257
# 2024-04-14    1.003257
# 2024-04-15    1.003257
# 2024-04-16    1.003257
# 2024-04-17    1.003257
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300028), 2024-03-02    1.150359
# 2024-03-03    0.965824
# 2024-03-04    0.995427
# 2024-03-05    0.990678
# 2024-03-06    0.991440
# 2024-03-07    0.991318
# 2024-03-08    0.991337
# 2024-03-09    0.991334
# 2024-03-10    0.991335
# 2024-03-11    0.991334
# 2024-03-12    0.991334
# 2024-03-13    0.991334
# 2024-03-14    0.991334
# 2024-03-15    0.991334
# 2024-03-16    0.991334
# 2024-03-17    0.991334
# 2024-03-18    0.991334
# 2024-03-19    0.991334
# 2024-03-20    0.991334
# 2024-03-21    0.991334
# 2024-03-22    0.991334
# 2024-03-23    0.991334
# 2024-03-24    0.991334
# 2024-03-25    0.991334
# 2024-03-26    0.991334
# 2024-03-27    0.991334
# 2024-03-28    0.991334
# 2024-03-29    0.991334
# 2024-03-30    0.991334
# 2024-03-31    0.991334
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300029), 2024-03-03    1.141460
# 2024-03-04    0.980443
# 2024-03-05    1.003156
# 2024-03-06    0.999952
# 2024-03-07    1.000404
# 2024-03-08    1.000340
# 2024-03-09    1.000349
# 2024-03-10    1.000348
# 2024-03-11    1.000348
# 2024-03-12    1.000348
# 2024-03-13    1.000348
# 2024-03-14    1.000348
# 2024-03-15    1.000348
# 2024-03-16    1.000348
# 2024-03-17    1.000348
# 2024-03-18    1.000348
# 2024-03-19    1.000348
# 2024-03-20    1.000348
# 2024-03-21    1.000348
# 2024-03-22    1.000348
# 2024-03-23    1.000348
# 2024-03-24    1.000348
# 2024-03-25    1.000348
# 2024-03-26    1.000348
# 2024-03-27    1.000348
# 2024-03-28    1.000348
# 2024-03-29    1.000348
# 2024-03-30    1.000348
# 2024-03-31    1.000348
# 2024-04-01    1.000348
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300030), 2024-03-06    1.159233
# 2024-03-07    0.985027
# 2024-03-08    1.011207
# 2024-03-09    1.007272
# 2024-03-10    1.007864
# 2024-03-11    1.007775
# 2024-03-12    1.007788
# 2024-03-13    1.007786
# 2024-03-14    1.007786
# 2024-03-15    1.007786
# 2024-03-16    1.007786
# 2024-03-17    1.007786
# 2024-03-18    1.007786
# 2024-03-19    1.007786
# 2024-03-20    1.007786
# 2024-03-21    1.007786
# 2024-03-22    1.007786
# 2024-03-23    1.007786
# 2024-03-24    1.007786
# 2024-03-25    1.007786
# 2024-03-26    1.007786
# 2024-03-27    1.007786
# 2024-03-28    1.007786
# 2024-03-29    1.007786
# 2024-03-30    1.007786
# 2024-03-31    1.007786
# 2024-04-01    1.007786
# 2024-04-02    1.007786
# 2024-04-03    1.007786
# 2024-04-04    1.007786
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300031), 2024-03-11    1.183459
# 2024-03-12    0.982150
# 2024-03-13    1.016393
# 2024-03-14    1.010568
# 2024-03-15    1.011559
# 2024-03-16    1.011390
# 2024-03-17    1.011419
# 2024-03-18    1.011414
# 2024-03-19    1.011415
# 2024-03-20    1.011415
# 2024-03-21    1.011415
# 2024-03-22    1.011415
# 2024-03-23    1.011415
# 2024-03-24    1.011415
# 2024-03-25    1.011415
# 2024-03-26    1.011415
# 2024-03-27    1.011415
# 2024-03-28    1.011415
# 2024-03-29    1.011415
# 2024-03-30    1.011415
# 2024-03-31    1.011415
# 2024-04-01    1.011415
# 2024-04-02    1.011415
# 2024-04-03    1.011415
# 2024-04-04    1.011415
# 2024-04-05    1.011415
# 2024-04-06    1.011415
# 2024-04-07    1.011415
# 2024-04-08    1.011415
# 2024-04-09    1.011415
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300032), 2024-03-19    1.131129
# 2024-03-20    0.982022
# 2024-03-21    1.001678
# 2024-03-22    0.999087
# 2024-03-23    0.999428
# 2024-03-24    0.999383
# 2024-03-25    0.999389
# 2024-03-26    0.999388
# 2024-03-27    0.999389
# 2024-03-28    0.999389
# 2024-03-29    0.999389
# 2024-03-30    0.999389
# 2024-03-31    0.999389
# 2024-04-01    0.999389
# 2024-04-02    0.999389
# 2024-04-03    0.999389
# 2024-04-04    0.999389
# 2024-04-05    0.999389
# 2024-04-06    0.999389
# 2024-04-07    0.999389
# 2024-04-08    0.999389
# 2024-04-09    0.999389
# 2024-04-10    0.999389
# 2024-04-11    0.999389
# 2024-04-12    0.999389
# 2024-04-13    0.999389
# 2024-04-14    0.999389
# 2024-04-15    0.999389
# 2024-04-16    0.999389
# 2024-04-17    0.999389
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300033), 2024-03-17    1.144821
# 2024-03-18    0.980569
# 2024-03-19    1.004135
# 2024-03-20    1.000754
# 2024-03-21    1.001239
# 2024-03-22    1.001169
# 2024-03-23    1.001179
# 2024-03-24    1.001178
# 2024-03-25    1.001178
# 2024-03-26    1.001178
# 2024-03-27    1.001178
# 2024-03-28    1.001178
# 2024-03-29    1.001178
# 2024-03-30    1.001178
# 2024-03-31    1.001178
# 2024-04-01    1.001178
# 2024-04-02    1.001178
# 2024-04-03    1.001178
# 2024-04-04    1.001178
# 2024-04-05    1.001178
# 2024-04-06    1.001178
# 2024-04-07    1.001178
# 2024-04-08    1.001178
# 2024-04-09    1.001178
# 2024-04-10    1.001178
# 2024-04-11    1.001178
# 2024-04-12    1.001178
# 2024-04-13    1.001178
# 2024-04-14    1.001178
# 2024-04-15    1.001178
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300034), 2024-03-17    0.347969
# 2024-03-18    1.109562
# 2024-03-19    0.984880
# 2024-03-20    1.005292
# 2024-03-21    1.001951
# 2024-03-22    1.002498
# 2024-03-23    1.002408
# 2024-03-24    1.002423
# 2024-03-25    1.002420
# 2024-03-26    1.002421
# 2024-03-27    1.002421
# 2024-03-28    1.002421
# 2024-03-29    1.002421
# 2024-03-30    1.002421
# 2024-03-31    1.002421
# 2024-04-01    1.002421
# 2024-04-02    1.002421
# 2024-04-03    1.002421
# 2024-04-04    1.002421
# 2024-04-05    1.002421
# 2024-04-06    1.002421
# 2024-04-07    1.002421
# 2024-04-08    1.002421
# 2024-04-09    1.002421
# 2024-04-10    1.002421
# 2024-04-11    1.002421
# 2024-04-12    1.002421
# 2024-04-13    1.002421
# 2024-04-14    1.002421
# 2024-04-15    1.002421
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300035), 2024-03-11    1.151889
# 2024-03-12    0.979745
# 2024-03-13    1.005471
# 2024-03-14    1.001626
# 2024-03-15    1.002201
# 2024-03-16    1.002115
# 2024-03-17    1.002128
# 2024-03-18    1.002126
# 2024-03-19    1.002126
# 2024-03-20    1.002126
# 2024-03-21    1.002126
# 2024-03-22    1.002126
# 2024-03-23    1.002126
# 2024-03-24    1.002126
# 2024-03-25    1.002126
# 2024-03-26    1.002126
# 2024-03-27    1.002126
# 2024-03-28    1.002126
# 2024-03-29    1.002126
# 2024-03-30    1.002126
# 2024-03-31    1.002126
# 2024-04-01    1.002126
# 2024-04-02    1.002126
# 2024-04-03    1.002126
# 2024-04-04    1.002126
# 2024-04-05    1.002126
# 2024-04-06    1.002126
# 2024-04-07    1.002126
# 2024-04-08    1.002126
# 2024-04-09    1.002126
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300036), 2024-03-06    0.998119
# 2024-03-07    0.998407
# 2024-03-08    0.998363
# 2024-03-09    0.998370
# 2024-03-10    0.998368
# 2024-03-11    0.998369
# 2024-03-12    0.998369
# 2024-03-13    0.998369
# 2024-03-14    0.998369
# 2024-03-15    0.998369
# 2024-03-16    0.998369
# 2024-03-17    0.998369
# 2024-03-18    0.998369
# 2024-03-19    0.998369
# 2024-03-20    0.998369
# 2024-03-21    0.998369
# 2024-03-22    0.998369
# 2024-03-23    0.998369
# 2024-03-24    0.998369
# 2024-03-25    0.998369
# 2024-03-26    0.998369
# 2024-03-27    0.998369
# 2024-03-28    0.998369
# 2024-03-29    0.998369
# 2024-03-30    0.998369
# 2024-03-31    0.998369
# 2024-04-01    0.998369
# 2024-04-02    0.998369
# 2024-04-03    0.998369
# 2024-04-04    0.998369
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300037), 2024-03-04    1.146445
# 2024-03-05    0.978712
# 2024-03-06    1.003253
# 2024-03-07    0.999662
# 2024-03-08    1.000187
# 2024-03-09    1.000111
# 2024-03-10    1.000122
# 2024-03-11    1.000120
# 2024-03-12    1.000120
# 2024-03-13    1.000120
# 2024-03-14    1.000120
# 2024-03-15    1.000120
# 2024-03-16    1.000120
# 2024-03-17    1.000120
# 2024-03-18    1.000120
# 2024-03-19    1.000120
# 2024-03-20    1.000120
# 2024-03-21    1.000120
# 2024-03-22    1.000120
# 2024-03-23    1.000120
# 2024-03-24    1.000120
# 2024-03-25    1.000120
# 2024-03-26    1.000120
# 2024-03-27    1.000120
# 2024-03-28    1.000120
# 2024-03-29    1.000120
# 2024-03-30    1.000120
# 2024-03-31    1.000120
# 2024-04-01    1.000120
# 2024-04-02    1.000120
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300038), 2024-03-10    1.133960
# 2024-03-11    0.985029
# 2024-03-12    1.004589
# 2024-03-13    1.002020
# 2024-03-14    1.002358
# 2024-03-15    1.002313
# 2024-03-16    1.002319
# 2024-03-17    1.002318
# 2024-03-18    1.002318
# 2024-03-19    1.002318
# 2024-03-20    1.002318
# 2024-03-21    1.002318
# 2024-03-22    1.002318
# 2024-03-23    1.002318
# 2024-03-24    1.002318
# 2024-03-25    1.002318
# 2024-03-26    1.002318
# 2024-03-27    1.002318
# 2024-03-28    1.002318
# 2024-03-29    1.002318
# 2024-03-30    1.002318
# 2024-03-31    1.002318
# 2024-04-01    1.002318
# 2024-04-02    1.002318
# 2024-04-03    1.002318
# 2024-04-04    1.002318
# 2024-04-05    1.002318
# 2024-04-06    1.002318
# 2024-04-07    1.002318
# 2024-04-08    1.002318
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(300039), 2024-03-02    0.538615
# 2024-03-03    1.073125
# 2024-03-04    0.990586
# 2024-03-05    1.003332
# 2024-03-06    1.001363
# 2024-03-07    1.001667
# 2024-03-08    1.001620
# 2024-03-09    1.001628
# 2024-03-10    1.001627
# 2024-03-11    1.001627
# 2024-03-12    1.001627
# 2024-03-13    1.001627
# 2024-03-14    1.001627
# 2024-03-15    1.001627
# 2024-03-16    1.001627
# 2024-03-17    1.001627
# 2024-03-18    1.001627
# 2024-03-19    1.001627
# 2024-03-20    1.001627
# 2024-03-21    1.001627
# 2024-03-22    1.001627
# 2024-03-23    1.001627
# 2024-03-24    1.001627
# 2024-03-25    1.001627
# 2024-03-26    1.001627
# 2024-03-27    1.001627
# 2024-03-28    1.001627
# 2024-03-29    1.001627
# 2024-03-30    1.001627
# 2024-03-31    1.001627
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600053), 2024-03-10    0.868986
# 2024-03-11    1.018227
# 2024-03-12    0.998534
# 2024-03-13    1.001132
# 2024-03-14    1.000790
# 2024-03-15    1.000835
# 2024-03-16    1.000829
# 2024-03-17    1.000830
# 2024-03-18    1.000829
# 2024-03-19    1.000829
# 2024-03-20    1.000829
# 2024-03-21    1.000829
# 2024-03-22    1.000829
# 2024-03-23    1.000829
# 2024-03-24    1.000829
# 2024-03-25    1.000829
# 2024-03-26    1.000829
# 2024-03-27    1.000829
# 2024-03-28    1.000829
# 2024-03-29    1.000829
# 2024-03-30    1.000829
# 2024-03-31    1.000829
# 2024-04-01    1.000829
# 2024-04-02    1.000829
# 2024-04-03    1.000829
# 2024-04-04    1.000829
# 2024-04-05    1.000829
# 2024-04-06    1.000829
# 2024-04-07    1.000829
# 2024-04-08    1.000829
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600054), 2024-03-17    1.160220
# 2024-03-18    0.969042
# 2024-03-19    1.000544
# 2024-03-20    0.995353
# 2024-03-21    0.996208
# 2024-03-22    0.996068
# 2024-03-23    0.996091
# 2024-03-24    0.996087
# 2024-03-25    0.996088
# 2024-03-26    0.996087
# 2024-03-27    0.996087
# 2024-03-28    0.996087
# 2024-03-29    0.996087
# 2024-03-30    0.996087
# 2024-03-31    0.996087
# 2024-04-01    0.996087
# 2024-04-02    0.996087
# 2024-04-03    0.996087
# 2024-04-04    0.996087
# 2024-04-05    0.996087
# 2024-04-06    0.996087
# 2024-04-07    0.996087
# 2024-04-08    0.996087
# 2024-04-09    0.996087
# 2024-04-10    0.996087
# 2024-04-11    0.996087
# 2024-04-12    0.996087
# 2024-04-13    0.996087
# 2024-04-14    0.996087
# 2024-04-15    0.996087
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600055), 2024-03-11    0.844342
# 2024-03-12    1.022045
# 2024-03-13    0.994720
# 2024-03-14    0.998922
# 2024-03-15    0.998275
# 2024-03-16    0.998375
# 2024-03-17    0.998360
# 2024-03-18    0.998362
# 2024-03-19    0.998362
# 2024-03-20    0.998362
# 2024-03-21    0.998362
# 2024-03-22    0.998362
# 2024-03-23    0.998362
# 2024-03-24    0.998362
# 2024-03-25    0.998362
# 2024-03-26    0.998362
# 2024-03-27    0.998362
# 2024-03-28    0.998362
# 2024-03-29    0.998362
# 2024-03-30    0.998362
# 2024-03-31    0.998362
# 2024-04-01    0.998362
# 2024-04-02    0.998362
# 2024-04-03    0.998362
# 2024-04-04    0.998362
# 2024-04-05    0.998362
# 2024-04-06    0.998362
# 2024-04-07    0.998362
# 2024-04-08    0.998362
# 2024-04-09    0.998362
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600056), 2024-03-05    1.142201
# 2024-03-06    0.980084
# 2024-03-07    1.003094
# 2024-03-08    0.999828
# 2024-03-09    1.000291
# 2024-03-10    1.000226
# 2024-03-11    1.000235
# 2024-03-12    1.000234
# 2024-03-13    1.000234
# 2024-03-14    1.000234
# 2024-03-15    1.000234
# 2024-03-16    1.000234
# 2024-03-17    1.000234
# 2024-03-18    1.000234
# 2024-03-19    1.000234
# 2024-03-20    1.000234
# 2024-03-21    1.000234
# 2024-03-22    1.000234
# 2024-03-23    1.000234
# 2024-03-24    1.000234
# 2024-03-25    1.000234
# 2024-03-26    1.000234
# 2024-03-27    1.000234
# 2024-03-28    1.000234
# 2024-03-29    1.000234
# 2024-03-30    1.000234
# 2024-03-31    1.000234
# 2024-04-01    1.000234
# 2024-04-02    1.000234
# 2024-04-03    1.000234
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600057), 2024-03-03    0.997170
# 2024-03-04    0.997572
# 2024-03-05    0.997515
# 2024-03-06    0.997523
# 2024-03-07    0.997522
# 2024-03-08    0.997522
# 2024-03-09    0.997522
# 2024-03-10    0.997522
# 2024-03-11    0.997522
# 2024-03-12    0.997522
# 2024-03-13    0.997522
# 2024-03-14    0.997522
# 2024-03-15    0.997522
# 2024-03-16    0.997522
# 2024-03-17    0.997522
# 2024-03-18    0.997522
# 2024-03-19    0.997522
# 2024-03-20    0.997522
# 2024-03-21    0.997522
# 2024-03-22    0.997522
# 2024-03-23    0.997522
# 2024-03-24    0.997522
# 2024-03-25    0.997522
# 2024-03-26    0.997522
# 2024-03-27    0.997522
# 2024-03-28    0.997522
# 2024-03-29    0.997522
# 2024-03-30    0.997522
# 2024-03-31    0.997522
# 2024-04-01    0.997522
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600058), 2024-03-04    0.160429
# 2024-03-05    1.145375
# 2024-03-06    0.979247
# 2024-03-07    1.007267
# 2024-03-08    1.002541
# 2024-03-09    1.003338
# 2024-03-10    1.003203
# 2024-03-11    1.003226
# 2024-03-12    1.003222
# 2024-03-13    1.003223
# 2024-03-14    1.003223
# 2024-03-15    1.003223
# 2024-03-16    1.003223
# 2024-03-17    1.003223
# 2024-03-18    1.003223
# 2024-03-19    1.003223
# 2024-03-20    1.003223
# 2024-03-21    1.003223
# 2024-03-22    1.003223
# 2024-03-23    1.003223
# 2024-03-24    1.003223
# 2024-03-25    1.003223
# 2024-03-26    1.003223
# 2024-03-27    1.003223
# 2024-03-28    1.003223
# 2024-03-29    1.003223
# 2024-03-30    1.003223
# 2024-03-31    1.003223
# 2024-04-01    1.003223
# 2024-04-02    1.003223
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600059), 2024-03-15    1.136406
# 2024-03-16    0.976658
# 2024-03-17    0.999114
# 2024-03-18    0.995958
# 2024-03-19    0.996401
# 2024-03-20    0.996339
# 2024-03-21    0.996348
# 2024-03-22    0.996347
# 2024-03-23    0.996347
# 2024-03-24    0.996347
# 2024-03-25    0.996347
# 2024-03-26    0.996347
# 2024-03-27    0.996347
# 2024-03-28    0.996347
# 2024-03-29    0.996347
# 2024-03-30    0.996347
# 2024-03-31    0.996347
# 2024-04-01    0.996347
# 2024-04-02    0.996347
# 2024-04-03    0.996347
# 2024-04-04    0.996347
# 2024-04-05    0.996347
# 2024-04-06    0.996347
# 2024-04-07    0.996347
# 2024-04-08    0.996347
# 2024-04-09    0.996347
# 2024-04-10    0.996347
# 2024-04-11    0.996347
# 2024-04-12    0.996347
# 2024-04-13    0.996347
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600060), 2024-03-17    1.156686
# 2024-03-18    0.972344
# 2024-03-19    1.001723
# 2024-03-20    0.997041
# 2024-03-21    0.997787
# 2024-03-22    0.997668
# 2024-03-23    0.997687
# 2024-03-24    0.997684
# 2024-03-25    0.997684
# 2024-03-26    0.997684
# 2024-03-27    0.997684
# 2024-03-28    0.997684
# 2024-03-29    0.997684
# 2024-03-30    0.997684
# 2024-03-31    0.997684
# 2024-04-01    0.997684
# 2024-04-02    0.997684
# 2024-04-03    0.997684
# 2024-04-04    0.997684
# 2024-04-05    0.997684
# 2024-04-06    0.997684
# 2024-04-07    0.997684
# 2024-04-08    0.997684
# 2024-04-09    0.997684
# 2024-04-10    0.997684
# 2024-04-11    0.997684
# 2024-04-12    0.997684
# 2024-04-13    0.997684
# 2024-04-14    0.997684
# 2024-04-15    0.997684
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600061), 2024-03-11    1.163827
# 2024-03-12    0.973698
# 2024-03-13    1.004759
# 2024-03-14    0.999685
# 2024-03-15    1.000513
# 2024-03-16    1.000378
# 2024-03-17    1.000400
# 2024-03-18    1.000397
# 2024-03-19    1.000397
# 2024-03-20    1.000397
# 2024-03-21    1.000397
# 2024-03-22    1.000397
# 2024-03-23    1.000397
# 2024-03-24    1.000397
# 2024-03-25    1.000397
# 2024-03-26    1.000397
# 2024-03-27    1.000397
# 2024-03-28    1.000397
# 2024-03-29    1.000397
# 2024-03-30    1.000397
# 2024-03-31    1.000397
# 2024-04-01    1.000397
# 2024-04-02    1.000397
# 2024-04-03    1.000397
# 2024-04-04    1.000397
# 2024-04-05    1.000397
# 2024-04-06    1.000397
# 2024-04-07    1.000397
# 2024-04-08    1.000397
# 2024-04-09    1.000397
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600062), 2024-03-10    1.149372
# 2024-03-11    0.978010
# 2024-03-12    1.003559
# 2024-03-13    0.999749
# 2024-03-14    1.000317
# 2024-03-15    1.000233
# 2024-03-16    1.000245
# 2024-03-17    1.000243
# 2024-03-18    1.000244
# 2024-03-19    1.000244
# 2024-03-20    1.000244
# 2024-03-21    1.000244
# 2024-03-22    1.000244
# 2024-03-23    1.000244
# 2024-03-24    1.000244
# 2024-03-25    1.000244
# 2024-03-26    1.000244
# 2024-03-27    1.000244
# 2024-03-28    1.000244
# 2024-03-29    1.000244
# 2024-03-30    1.000244
# 2024-03-31    1.000244
# 2024-04-01    1.000244
# 2024-04-02    1.000244
# 2024-04-03    1.000244
# 2024-04-04    1.000244
# 2024-04-05    1.000244
# 2024-04-06    1.000244
# 2024-04-07    1.000244
# 2024-04-08    1.000244
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600063), 2024-03-05    0.826524
# 2024-03-06    1.028986
# 2024-03-07    0.994055
# 2024-03-08    1.000081
# 2024-03-09    0.999042
# 2024-03-10    0.999221
# 2024-03-11    0.999190
# 2024-03-12    0.999195
# 2024-03-13    0.999195
# 2024-03-14    0.999195
# 2024-03-15    0.999195
# 2024-03-16    0.999195
# 2024-03-17    0.999195
# 2024-03-18    0.999195
# 2024-03-19    0.999195
# 2024-03-20    0.999195
# 2024-03-21    0.999195
# 2024-03-22    0.999195
# 2024-03-23    0.999195
# 2024-03-24    0.999195
# 2024-03-25    0.999195
# 2024-03-26    0.999195
# 2024-03-27    0.999195
# 2024-03-28    0.999195
# 2024-03-29    0.999195
# 2024-03-30    0.999195
# 2024-03-31    0.999195
# 2024-04-01    0.999195
# 2024-04-02    0.999195
# 2024-04-03    0.999195
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600064), 2024-03-03    1.152102
# 2024-03-04    0.971795
# 2024-03-05    1.000013
# 2024-03-06    0.995597
# 2024-03-07    0.996288
# 2024-03-08    0.996180
# 2024-03-09    0.996197
# 2024-03-10    0.996194
# 2024-03-11    0.996195
# 2024-03-12    0.996195
# 2024-03-13    0.996195
# 2024-03-14    0.996195
# 2024-03-15    0.996195
# 2024-03-16    0.996195
# 2024-03-17    0.996195
# 2024-03-18    0.996195
# 2024-03-19    0.996195
# 2024-03-20    0.996195
# 2024-03-21    0.996195
# 2024-03-22    0.996195
# 2024-03-23    0.996195
# 2024-03-24    0.996195
# 2024-03-25    0.996195
# 2024-03-26    0.996195
# 2024-03-27    0.996195
# 2024-03-28    0.996195
# 2024-03-29    0.996195
# 2024-03-30    0.996195
# 2024-03-31    0.996195
# 2024-04-01    0.996195
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600065), 2024-03-13    1.0
# 2024-03-14    1.0
# 2024-03-15    1.0
# 2024-03-16    1.0
# 2024-03-17    1.0
# 2024-03-18    1.0
# 2024-03-19    1.0
# 2024-03-20    1.0
# 2024-03-21    1.0
# 2024-03-22    1.0
# 2024-03-23    1.0
# 2024-03-24    1.0
# 2024-03-25    1.0
# 2024-03-26    1.0
# 2024-03-27    1.0
# 2024-03-28    1.0
# 2024-03-29    1.0
# 2024-03-30    1.0
# 2024-03-31    1.0
# 2024-04-01    1.0
# 2024-04-02    1.0
# 2024-04-03    1.0
# 2024-04-04    1.0
# 2024-04-05    1.0
# 2024-04-06    1.0
# 2024-04-07    1.0
# 2024-04-08    1.0
# 2024-04-09    1.0
# 2024-04-10    1.0
# 2024-04-11    1.0
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600066), 2024-03-09    1.169544
# 2024-03-10    0.974188
# 2024-03-11    1.006819
# 2024-03-12    1.001369
# 2024-03-13    1.002279
# 2024-03-14    1.002127
# 2024-03-15    1.002152
# 2024-03-16    1.002148
# 2024-03-17    1.002149
# 2024-03-18    1.002149
# 2024-03-19    1.002149
# 2024-03-20    1.002149
# 2024-03-21    1.002149
# 2024-03-22    1.002149
# 2024-03-23    1.002149
# 2024-03-24    1.002149
# 2024-03-25    1.002149
# 2024-03-26    1.002149
# 2024-03-27    1.002149
# 2024-03-28    1.002149
# 2024-03-29    1.002149
# 2024-03-30    1.002149
# 2024-03-31    1.002149
# 2024-04-01    1.002149
# 2024-04-02    1.002149
# 2024-04-03    1.002149
# 2024-04-04    1.002149
# 2024-04-05    1.002149
# 2024-04-06    1.002149
# 2024-04-07    1.002149
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600067), 2024-03-03    1.129572
# 2024-03-04    0.983348
# 2024-03-05    1.002277
# 2024-03-06    0.999827
# 2024-03-07    1.000144
# 2024-03-08    1.000103
# 2024-03-09    1.000108
# 2024-03-10    1.000108
# 2024-03-11    1.000108
# 2024-03-12    1.000108
# 2024-03-13    1.000108
# 2024-03-14    1.000108
# 2024-03-15    1.000108
# 2024-03-16    1.000108
# 2024-03-17    1.000108
# 2024-03-18    1.000108
# 2024-03-19    1.000108
# 2024-03-20    1.000108
# 2024-03-21    1.000108
# 2024-03-22    1.000108
# 2024-03-23    1.000108
# 2024-03-24    1.000108
# 2024-03-25    1.000108
# 2024-03-26    1.000108
# 2024-03-27    1.000108
# 2024-03-28    1.000108
# 2024-03-29    1.000108
# 2024-03-30    1.000108
# 2024-03-31    1.000108
# 2024-04-01    1.000108
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600068), 2024-03-20    1.122045
# 2024-03-21    0.980085
# 2024-03-22    0.998046
# 2024-03-23    0.995773
# 2024-03-24    0.996061
# 2024-03-25    0.996024
# 2024-03-26    0.996029
# 2024-03-27    0.996028
# 2024-03-28    0.996028
# 2024-03-29    0.996028
# 2024-03-30    0.996028
# 2024-03-31    0.996028
# 2024-04-01    0.996028
# 2024-04-02    0.996028
# 2024-04-03    0.996028
# 2024-04-04    0.996028
# 2024-04-05    0.996028
# 2024-04-06    0.996028
# 2024-04-07    0.996028
# 2024-04-08    0.996028
# 2024-04-09    0.996028
# 2024-04-10    0.996028
# 2024-04-11    0.996028
# 2024-04-12    0.996028
# 2024-04-13    0.996028
# 2024-04-14    0.996028
# 2024-04-15    0.996028
# 2024-04-16    0.996028
# 2024-04-17    0.996028
# 2024-04-18    0.996028
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600069), 2024-03-13    1.155309
# 2024-03-14    0.967729
# 2024-03-15    0.998185
# 2024-03-16    0.993240
# 2024-03-17    0.994043
# 2024-03-18    0.993913
# 2024-03-19    0.993934
# 2024-03-20    0.993931
# 2024-03-21    0.993931
# 2024-03-22    0.993931
# 2024-03-23    0.993931
# 2024-03-24    0.993931
# 2024-03-25    0.993931
# 2024-03-26    0.993931
# 2024-03-27    0.993931
# 2024-03-28    0.993931
# 2024-03-29    0.993931
# 2024-03-30    0.993931
# 2024-03-31    0.993931
# 2024-04-01    0.993931
# 2024-04-02    0.993931
# 2024-04-03    0.993931
# 2024-04-04    0.993931
# 2024-04-05    0.993931
# 2024-04-06    0.993931
# 2024-04-07    0.993931
# 2024-04-08    0.993931
# 2024-04-09    0.993931
# 2024-04-10    0.993931
# 2024-04-11    0.993931
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600070), 2024-03-19    1.151699
# 2024-03-20    0.979640
# 2024-03-21    1.005345
# 2024-03-22    1.001505
# 2024-03-23    1.002078
# 2024-03-24    1.001993
# 2024-03-25    1.002005
# 2024-03-26    1.002003
# 2024-03-27    1.002004
# 2024-03-28    1.002004
# 2024-03-29    1.002004
# 2024-03-30    1.002004
# 2024-03-31    1.002004
# 2024-04-01    1.002004
# 2024-04-02    1.002004
# 2024-04-03    1.002004
# 2024-04-04    1.002004
# 2024-04-05    1.002004
# 2024-04-06    1.002004
# 2024-04-07    1.002004
# 2024-04-08    1.002004
# 2024-04-09    1.002004
# 2024-04-10    1.002004
# 2024-04-11    1.002004
# 2024-04-12    1.002004
# 2024-04-13    1.002004
# 2024-04-14    1.002004
# 2024-04-15    1.002004
# 2024-04-16    1.002004
# 2024-04-17    1.002004
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600071), 2024-03-15    1.102254
# 2024-03-16    0.989650
# 2024-03-17    1.001154
# 2024-03-18    0.999979
# 2024-03-19    1.000099
# 2024-03-20    1.000086
# 2024-03-21    1.000088
# 2024-03-22    1.000087
# 2024-03-23    1.000087
# 2024-03-24    1.000087
# 2024-03-25    1.000087
# 2024-03-26    1.000087
# 2024-03-27    1.000087
# 2024-03-28    1.000087
# 2024-03-29    1.000087
# 2024-03-30    1.000087
# 2024-03-31    1.000087
# 2024-04-01    1.000087
# 2024-04-02    1.000087
# 2024-04-03    1.000087
# 2024-04-04    1.000087
# 2024-04-05    1.000087
# 2024-04-06    1.000087
# 2024-04-07    1.000087
# 2024-04-08    1.000087
# 2024-04-09    1.000087
# 2024-04-10    1.000087
# 2024-04-11    1.000087
# 2024-04-12    1.000087
# 2024-04-13    1.000087
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600072), 2024-03-11    1.127072
# 2024-03-12    0.976996
# 2024-03-13    0.996979
# 2024-03-14    0.994318
# 2024-03-15    0.994673
# 2024-03-16    0.994625
# 2024-03-17    0.994632
# 2024-03-18    0.994631
# 2024-03-19    0.994631
# 2024-03-20    0.994631
# 2024-03-21    0.994631
# 2024-03-22    0.994631
# 2024-03-23    0.994631
# 2024-03-24    0.994631
# 2024-03-25    0.994631
# 2024-03-26    0.994631
# 2024-03-27    0.994631
# 2024-03-28    0.994631
# 2024-03-29    0.994631
# 2024-03-30    0.994631
# 2024-03-31    0.994631
# 2024-04-01    0.994631
# 2024-04-02    0.994631
# 2024-04-03    0.994631
# 2024-04-04    0.994631
# 2024-04-05    0.994631
# 2024-04-06    0.994631
# 2024-04-07    0.994631
# 2024-04-08    0.994631
# 2024-04-09    0.994631
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600073), 2024-03-11    1.147858
# 2024-03-12    0.982009
# 2024-03-13    1.005972
# 2024-03-14    1.002509
# 2024-03-15    1.003010
# 2024-03-16    1.002937
# 2024-03-17    1.002948
# 2024-03-18    1.002946
# 2024-03-19    1.002947
# 2024-03-20    1.002947
# 2024-03-21    1.002947
# 2024-03-22    1.002947
# 2024-03-23    1.002947
# 2024-03-24    1.002947
# 2024-03-25    1.002947
# 2024-03-26    1.002947
# 2024-03-27    1.002947
# 2024-03-28    1.002947
# 2024-03-29    1.002947
# 2024-03-30    1.002947
# 2024-03-31    1.002947
# 2024-04-01    1.002947
# 2024-04-02    1.002947
# 2024-04-03    1.002947
# 2024-04-04    1.002947
# 2024-04-05    1.002947
# 2024-04-06    1.002947
# 2024-04-07    1.002947
# 2024-04-08    1.002947
# 2024-04-09    1.002947
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600074), 2024-03-02    0.580047
# 2024-03-03    1.062013
# 2024-03-04    0.994091
# 2024-03-05    1.003663
# 2024-03-06    1.002314
# 2024-03-07    1.002504
# 2024-03-08    1.002477
# 2024-03-09    1.002481
# 2024-03-10    1.002481
# 2024-03-11    1.002481
# 2024-03-12    1.002481
# 2024-03-13    1.002481
# 2024-03-14    1.002481
# 2024-03-15    1.002481
# 2024-03-16    1.002481
# 2024-03-17    1.002481
# 2024-03-18    1.002481
# 2024-03-19    1.002481
# 2024-03-20    1.002481
# 2024-03-21    1.002481
# 2024-03-22    1.002481
# 2024-03-23    1.002481
# 2024-03-24    1.002481
# 2024-03-25    1.002481
# 2024-03-26    1.002481
# 2024-03-27    1.002481
# 2024-03-28    1.002481
# 2024-03-29    1.002481
# 2024-03-30    1.002481
# 2024-03-31    1.002481
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600075), 2024-03-18    1.167712
# 2024-03-19    0.975905
# 2024-03-20    1.007411
# 2024-03-21    1.002236
# 2024-03-22    1.003086
# 2024-03-23    1.002946
# 2024-03-24    1.002969
# 2024-03-25    1.002966
# 2024-03-26    1.002966
# 2024-03-27    1.002966
# 2024-03-28    1.002966
# 2024-03-29    1.002966
# 2024-03-30    1.002966
# 2024-03-31    1.002966
# 2024-04-01    1.002966
# 2024-04-02    1.002966
# 2024-04-03    1.002966
# 2024-04-04    1.002966
# 2024-04-05    1.002966
# 2024-04-06    1.002966
# 2024-04-07    1.002966
# 2024-04-08    1.002966
# 2024-04-09    1.002966
# 2024-04-10    1.002966
# 2024-04-11    1.002966
# 2024-04-12    1.002966
# 2024-04-13    1.002966
# 2024-04-14    1.002966
# 2024-04-15    1.002966
# 2024-04-16    1.002966
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600076), 2024-03-06    1.155722
# 2024-03-07    0.975921
# 2024-03-08    1.003893
# 2024-03-09    0.999541
# 2024-03-10    1.000218
# 2024-03-11    1.000113
# 2024-03-12    1.000130
# 2024-03-13    1.000127
# 2024-03-14    1.000127
# 2024-03-15    1.000127
# 2024-03-16    1.000127
# 2024-03-17    1.000127
# 2024-03-18    1.000127
# 2024-03-19    1.000127
# 2024-03-20    1.000127
# 2024-03-21    1.000127
# 2024-03-22    1.000127
# 2024-03-23    1.000127
# 2024-03-24    1.000127
# 2024-03-25    1.000127
# 2024-03-26    1.000127
# 2024-03-27    1.000127
# 2024-03-28    1.000127
# 2024-03-29    1.000127
# 2024-03-30    1.000127
# 2024-03-31    1.000127
# 2024-04-01    1.000127
# 2024-04-02    1.000127
# 2024-04-03    1.000127
# 2024-04-04    1.000127
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600077), 2024-03-02    1.117610
# 2024-03-03    0.990960
# 2024-03-04    1.005312
# 2024-03-05    1.003686
# 2024-03-06    1.003870
# 2024-03-07    1.003849
# 2024-03-08    1.003852
# 2024-03-09    1.003851
# 2024-03-10    1.003851
# 2024-03-11    1.003851
# 2024-03-12    1.003851
# 2024-03-13    1.003851
# 2024-03-14    1.003851
# 2024-03-15    1.003851
# 2024-03-16    1.003851
# 2024-03-17    1.003851
# 2024-03-18    1.003851
# 2024-03-19    1.003851
# 2024-03-20    1.003851
# 2024-03-21    1.003851
# 2024-03-22    1.003851
# 2024-03-23    1.003851
# 2024-03-24    1.003851
# 2024-03-25    1.003851
# 2024-03-26    1.003851
# 2024-03-27    1.003851
# 2024-03-28    1.003851
# 2024-03-29    1.003851
# 2024-03-30    1.003851
# 2024-03-31    1.003851
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600078), 2024-03-13    0.672573
# 2024-03-14    1.055789
# 2024-03-15    0.992692
# 2024-03-16    1.003081
# 2024-03-17    1.001371
# 2024-03-18    1.001652
# 2024-03-19    1.001606
# 2024-03-20    1.001614
# 2024-03-21    1.001612
# 2024-03-22    1.001612
# 2024-03-23    1.001612
# 2024-03-24    1.001612
# 2024-03-25    1.001612
# 2024-03-26    1.001612
# 2024-03-27    1.001612
# 2024-03-28    1.001612
# 2024-03-29    1.001612
# 2024-03-30    1.001612
# 2024-03-31    1.001612
# 2024-04-01    1.001612
# 2024-04-02    1.001612
# 2024-04-03    1.001612
# 2024-04-04    1.001612
# 2024-04-05    1.001612
# 2024-04-06    1.001612
# 2024-04-07    1.001612
# 2024-04-08    1.001612
# 2024-04-09    1.001612
# 2024-04-10    1.001612
# 2024-04-11    1.001612
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600079), 2024-03-17    1.134802
# 2024-03-18    0.969353
# 2024-03-19    0.993474
# 2024-03-20    0.989958
# 2024-03-21    0.990470
# 2024-03-22    0.990396
# 2024-03-23    0.990407
# 2024-03-24    0.990405
# 2024-03-25    0.990405
# 2024-03-26    0.990405
# 2024-03-27    0.990405
# 2024-03-28    0.990405
# 2024-03-29    0.990405
# 2024-03-30    0.990405
# 2024-03-31    0.990405
# 2024-04-01    0.990405
# 2024-04-02    0.990405
# 2024-04-03    0.990405
# 2024-04-04    0.990405
# 2024-04-05    0.990405
# 2024-04-06    0.990405
# 2024-04-07    0.990405
# 2024-04-08    0.990405
# 2024-04-09    0.990405
# 2024-04-10    0.990405
# 2024-04-11    0.990405
# 2024-04-12    0.990405
# 2024-04-13    0.990405
# 2024-04-14    0.990405
# 2024-04-15    0.990405
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600080), 2024-03-13    1.131137
# 2024-03-14    0.984280
# 2024-03-15    1.003347
# 2024-03-16    1.000871
# 2024-03-17    1.001193
# 2024-03-18    1.001151
# 2024-03-19    1.001156
# 2024-03-20    1.001156
# 2024-03-21    1.001156
# 2024-03-22    1.001156
# 2024-03-23    1.001156
# 2024-03-24    1.001156
# 2024-03-25    1.001156
# 2024-03-26    1.001156
# 2024-03-27    1.001156
# 2024-03-28    1.001156
# 2024-03-29    1.001156
# 2024-03-30    1.001156
# ...
# 2024-04-08    0.996110
# 2024-04-09    0.996110
# 2024-04-10    0.996110
# 2024-04-11    0.996110
# 2024-04-12    0.996110
# 2024-04-13    0.996110
# 2024-04-14    0.996110
# 2024-04-15    0.996110
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600107), 2024-03-09    1.152163
# 2024-03-10    0.973766
# 2024-03-11    1.001388
# 2024-03-12    0.997111
# 2024-03-13    0.997773
# 2024-03-14    0.997671
# 2024-03-15    0.997687
# 2024-03-16    0.997684
# 2024-03-17    0.997685
# 2024-03-18    0.997684
# 2024-03-19    0.997684
# 2024-03-20    0.997684
# 2024-03-21    0.997684
# 2024-03-22    0.997684
# 2024-03-23    0.997684
# 2024-03-24    0.997684
# 2024-03-25    0.997684
# 2024-03-26    0.997684
# 2024-03-27    0.997684
# 2024-03-28    0.997684
# 2024-03-29    0.997684
# 2024-03-30    0.997684
# 2024-03-31    0.997684
# 2024-04-01    0.997684
# 2024-04-02    0.997684
# 2024-04-03    0.997684
# 2024-04-04    0.997684
# 2024-04-05    0.997684
# 2024-04-06    0.997684
# 2024-04-07    0.997684
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600108), 2024-03-16    1.163439
# 2024-03-17    0.978703
# 2024-03-18    1.008036
# 2024-03-19    1.003379
# 2024-03-20    1.004118
# 2024-03-21    1.004001
# 2024-03-22    1.004020
# 2024-03-23    1.004017
# 2024-03-24    1.004017
# 2024-03-25    1.004017
# 2024-03-26    1.004017
# 2024-03-27    1.004017
# 2024-03-28    1.004017
# 2024-03-29    1.004017
# 2024-03-30    1.004017
# 2024-03-31    1.004017
# 2024-04-01    1.004017
# 2024-04-02    1.004017
# 2024-04-03    1.004017
# 2024-04-04    1.004017
# 2024-04-05    1.004017
# 2024-04-06    1.004017
# 2024-04-07    1.004017
# 2024-04-08    1.004017
# 2024-04-09    1.004017
# 2024-04-10    1.004017
# 2024-04-11    1.004017
# 2024-04-12    1.004017
# 2024-04-13    1.004017
# 2024-04-14    1.004017
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600109), 2024-03-16    1.153849
# 2024-03-17    0.980259
# 2024-03-18    1.006374
# 2024-03-19    1.002445
# 2024-03-20    1.003036
# 2024-03-21    1.002948
# 2024-03-22    1.002961
# 2024-03-23    1.002959
# 2024-03-24    1.002959
# 2024-03-25    1.002959
# 2024-03-26    1.002959
# 2024-03-27    1.002959
# 2024-03-28    1.002959
# 2024-03-29    1.002959
# 2024-03-30    1.002959
# 2024-03-31    1.002959
# 2024-04-01    1.002959
# 2024-04-02    1.002959
# 2024-04-03    1.002959
# 2024-04-04    1.002959
# 2024-04-05    1.002959
# 2024-04-06    1.002959
# 2024-04-07    1.002959
# 2024-04-08    1.002959
# 2024-04-09    1.002959
# 2024-04-10    1.002959
# 2024-04-11    1.002959
# 2024-04-12    1.002959
# 2024-04-13    1.002959
# 2024-04-14    1.002959
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600110), 2024-03-11    1.175487
# 2024-03-12    0.973653
# 2024-03-13    1.008308
# 2024-03-14    1.002358
# 2024-03-15    1.003379
# 2024-03-16    1.003204
# 2024-03-17    1.003234
# 2024-03-18    1.003229
# 2024-03-19    1.003230
# 2024-03-20    1.003230
# 2024-03-21    1.003230
# 2024-03-22    1.003230
# 2024-03-23    1.003230
# 2024-03-24    1.003230
# 2024-03-25    1.003230
# 2024-03-26    1.003230
# 2024-03-27    1.003230
# 2024-03-28    1.003230
# 2024-03-29    1.003230
# 2024-03-30    1.003230
# 2024-03-31    1.003230
# 2024-04-01    1.003230
# 2024-04-02    1.003230
# 2024-04-03    1.003230
# 2024-04-04    1.003230
# 2024-04-05    1.003230
# 2024-04-06    1.003230
# 2024-04-07    1.003230
# 2024-04-08    1.003230
# 2024-04-09    1.003230
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600111), 2024-03-19    1.162183
# 2024-03-20    0.974052
# 2024-03-21    1.004506
# 2024-03-22    0.999576
# 2024-03-23    1.000374
# 2024-03-24    1.000245
# 2024-03-25    1.000266
# 2024-03-26    1.000262
# 2024-03-27    1.000263
# 2024-03-28    1.000263
# 2024-03-29    1.000263
# 2024-03-30    1.000263
# 2024-03-31    1.000263
# 2024-04-01    1.000263
# 2024-04-02    1.000263
# 2024-04-03    1.000263
# 2024-04-04    1.000263
# 2024-04-05    1.000263
# 2024-04-06    1.000263
# 2024-04-07    1.000263
# 2024-04-08    1.000263
# 2024-04-09    1.000263
# 2024-04-10    1.000263
# 2024-04-11    1.000263
# 2024-04-12    1.000263
# 2024-04-13    1.000263
# 2024-04-14    1.000263
# 2024-04-15    1.000263
# 2024-04-16    1.000263
# 2024-04-17    1.000263
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600112), 2024-03-17    1.155932
# 2024-03-18    0.978536
# 2024-03-19    1.005760
# 2024-03-20    1.001582
# 2024-03-21    1.002223
# 2024-03-22    1.002125
# 2024-03-23    1.002140
# 2024-03-24    1.002138
# 2024-03-25    1.002138
# 2024-03-26    1.002138
# 2024-03-27    1.002138
# 2024-03-28    1.002138
# 2024-03-29    1.002138
# 2024-03-30    1.002138
# 2024-03-31    1.002138
# 2024-04-01    1.002138
# 2024-04-02    1.002138
# 2024-04-03    1.002138
# 2024-04-04    1.002138
# 2024-04-05    1.002138
# 2024-04-06    1.002138
# 2024-04-07    1.002138
# 2024-04-08    1.002138
# 2024-04-09    1.002138
# 2024-04-10    1.002138
# 2024-04-11    1.002138
# 2024-04-12    1.002138
# 2024-04-13    1.002138
# 2024-04-14    1.002138
# 2024-04-15    1.002138
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600113), 2024-03-13    1.141703
# 2024-03-14    0.979305
# 2024-03-15    1.002404
# 2024-03-16    0.999119
# 2024-03-17    0.999586
# 2024-03-18    0.999520
# 2024-03-19    0.999529
# 2024-03-20    0.999528
# 2024-03-21    0.999528
# 2024-03-22    0.999528
# 2024-03-23    0.999528
# 2024-03-24    0.999528
# 2024-03-25    0.999528
# 2024-03-26    0.999528
# 2024-03-27    0.999528
# 2024-03-28    0.999528
# 2024-03-29    0.999528
# 2024-03-30    0.999528
# 2024-03-31    0.999528
# 2024-04-01    0.999528
# 2024-04-02    0.999528
# 2024-04-03    0.999528
# 2024-04-04    0.999528
# 2024-04-05    0.999528
# 2024-04-06    0.999528
# 2024-04-07    0.999528
# 2024-04-08    0.999528
# 2024-04-09    0.999528
# 2024-04-10    0.999528
# 2024-04-11    0.999528
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600114), 2024-03-04    1.0
# 2024-03-05    1.0
# 2024-03-06    1.0
# 2024-03-07    1.0
# 2024-03-08    1.0
# 2024-03-09    1.0
# 2024-03-10    1.0
# 2024-03-11    1.0
# 2024-03-12    1.0
# 2024-03-13    1.0
# 2024-03-14    1.0
# 2024-03-15    1.0
# 2024-03-16    1.0
# 2024-03-17    1.0
# 2024-03-18    1.0
# 2024-03-19    1.0
# 2024-03-20    1.0
# 2024-03-21    1.0
# 2024-03-22    1.0
# 2024-03-23    1.0
# 2024-03-24    1.0
# 2024-03-25    1.0
# 2024-03-26    1.0
# 2024-03-27    1.0
# 2024-03-28    1.0
# 2024-03-29    1.0
# 2024-03-30    1.0
# 2024-03-31    1.0
# 2024-04-01    1.0
# 2024-04-02    1.0
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600115), 2024-03-18    0.024652
# 2024-03-19    1.165125
# 2024-03-20    0.978657
# 2024-03-21    1.009145
# 2024-03-22    1.004160
# 2024-03-23    1.004975
# 2024-03-24    1.004842
# 2024-03-25    1.004863
# 2024-03-26    1.004860
# 2024-03-27    1.004860
# 2024-03-28    1.004860
# 2024-03-29    1.004860
# 2024-03-30    1.004860
# 2024-03-31    1.004860
# 2024-04-01    1.004860
# 2024-04-02    1.004860
# 2024-04-03    1.004860
# 2024-04-04    1.004860
# 2024-04-05    1.004860
# 2024-04-06    1.004860
# 2024-04-07    1.004860
# 2024-04-08    1.004860
# 2024-04-09    1.004860
# 2024-04-10    1.004860
# 2024-04-11    1.004860
# 2024-04-12    1.004860
# 2024-04-13    1.004860
# 2024-04-14    1.004860
# 2024-04-15    1.004860
# 2024-04-16    1.004860
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600116), 2024-03-09    1.160499
# 2024-03-10    0.978567
# 2024-03-11    1.007088
# 2024-03-12    1.002617
# 2024-03-13    1.003318
# 2024-03-14    1.003208
# 2024-03-15    1.003225
# 2024-03-16    1.003223
# 2024-03-17    1.003223
# 2024-03-18    1.003223
# 2024-03-19    1.003223
# 2024-03-20    1.003223
# 2024-03-21    1.003223
# 2024-03-22    1.003223
# 2024-03-23    1.003223
# 2024-03-24    1.003223
# 2024-03-25    1.003223
# 2024-03-26    1.003223
# 2024-03-27    1.003223
# 2024-03-28    1.003223
# 2024-03-29    1.003223
# 2024-03-30    1.003223
# 2024-03-31    1.003223
# 2024-04-01    1.003223
# 2024-04-02    1.003223
# 2024-04-03    1.003223
# 2024-04-04    1.003223
# 2024-04-05    1.003223
# 2024-04-06    1.003223
# 2024-04-07    1.003223
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600117), 2024-03-16    1.181685
# 2024-03-17    0.976509
# 2024-03-18    1.012134
# 2024-03-19    1.005948
# 2024-03-20    1.007022
# 2024-03-21    1.006836
# 2024-03-22    1.006868
# 2024-03-23    1.006863
# 2024-03-24    1.006864
# 2024-03-25    1.006864
# 2024-03-26    1.006864
# 2024-03-27    1.006864
# 2024-03-28    1.006864
# 2024-03-29    1.006864
# 2024-03-30    1.006864
# 2024-03-31    1.006864
# 2024-04-01    1.006864
# 2024-04-02    1.006864
# 2024-04-03    1.006864
# 2024-04-04    1.006864
# 2024-04-05    1.006864
# 2024-04-06    1.006864
# 2024-04-07    1.006864
# 2024-04-08    1.006864
# 2024-04-09    1.006864
# 2024-04-10    1.006864
# 2024-04-11    1.006864
# 2024-04-12    1.006864
# 2024-04-13    1.006864
# 2024-04-14    1.006864
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600118), 2024-03-13    1.152706
# 2024-03-14    0.975764
# 2024-03-15    1.002925
# 2024-03-16    0.998755
# 2024-03-17    0.999395
# 2024-03-18    0.999297
# 2024-03-19    0.999312
# 2024-03-20    0.999310
# 2024-03-21    0.999310
# 2024-03-22    0.999310
# 2024-03-23    0.999310
# 2024-03-24    0.999310
# 2024-03-25    0.999310
# 2024-03-26    0.999310
# 2024-03-27    0.999310
# 2024-03-28    0.999310
# 2024-03-29    0.999310
# 2024-03-30    0.999310
# 2024-03-31    0.999310
# 2024-04-01    0.999310
# 2024-04-02    0.999310
# 2024-04-03    0.999310
# 2024-04-04    0.999310
# 2024-04-05    0.999310
# 2024-04-06    0.999310
# 2024-04-07    0.999310
# 2024-04-08    0.999310
# 2024-04-09    0.999310
# 2024-04-10    0.999310
# 2024-04-11    0.999310
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600119), 2024-03-17    1.149738
# 2024-03-18    0.975738
# 2024-03-19    1.002071
# 2024-03-20    0.998085
# 2024-03-21    0.998689
# 2024-03-22    0.998597
# 2024-03-23    0.998611
# 2024-03-24    0.998609
# 2024-03-25    0.998609
# 2024-03-26    0.998609
# 2024-03-27    0.998609
# 2024-03-28    0.998609
# 2024-03-29    0.998609
# 2024-03-30    0.998609
# 2024-03-31    0.998609
# 2024-04-01    0.998609
# 2024-04-02    0.998609
# 2024-04-03    0.998609
# 2024-04-04    0.998609
# 2024-04-05    0.998609
# 2024-04-06    0.998609
# 2024-04-07    0.998609
# 2024-04-08    0.998609
# 2024-04-09    0.998609
# 2024-04-10    0.998609
# 2024-04-11    0.998609
# 2024-04-12    0.998609
# 2024-04-13    0.998609
# 2024-04-14    0.998609
# 2024-04-15    0.998609
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600120), 2024-03-14    1.145977
# 2024-03-15    0.980390
# 2024-03-16    1.004317
# 2024-03-17    1.000859
# 2024-03-18    1.001359
# 2024-03-19    1.001287
# 2024-03-20    1.001297
# 2024-03-21    1.001296
# 2024-03-22    1.001296
# 2024-03-23    1.001296
# 2024-03-24    1.001296
# 2024-03-25    1.001296
# 2024-03-26    1.001296
# 2024-03-27    1.001296
# 2024-03-28    1.001296
# 2024-03-29    1.001296
# 2024-03-30    1.001296
# 2024-03-31    1.001296
# 2024-04-01    1.001296
# 2024-04-02    1.001296
# 2024-04-03    1.001296
# 2024-04-04    1.001296
# 2024-04-05    1.001296
# 2024-04-06    1.001296
# 2024-04-07    1.001296
# 2024-04-08    1.001296
# 2024-04-09    1.001296
# 2024-04-10    1.001296
# 2024-04-11    1.001296
# 2024-04-12    1.001296
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600121), 2024-03-06    1.161807
# 2024-03-07    0.976868
# 2024-03-08    1.006307
# 2024-03-09    1.001621
# 2024-03-10    1.002367
# 2024-03-11    1.002248
# 2024-03-12    1.002267
# 2024-03-13    1.002264
# 2024-03-14    1.002265
# 2024-03-15    1.002265
# 2024-03-16    1.002265
# 2024-03-17    1.002265
# 2024-03-18    1.002265
# 2024-03-19    1.002265
# 2024-03-20    1.002265
# 2024-03-21    1.002265
# 2024-03-22    1.002265
# 2024-03-23    1.002265
# 2024-03-24    1.002265
# 2024-03-25    1.002265
# 2024-03-26    1.002265
# 2024-03-27    1.002265
# 2024-03-28    1.002265
# 2024-03-29    1.002265
# 2024-03-30    1.002265
# 2024-03-31    1.002265
# 2024-04-01    1.002265
# 2024-04-02    1.002265
# 2024-04-03    1.002265
# 2024-04-04    1.002265
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600122), 2024-03-06    1.149756
# 2024-03-07    0.974827
# 2024-03-08    1.001442
# 2024-03-09    0.997392
# 2024-03-10    0.998008
# 2024-03-11    0.997915
# 2024-03-12    0.997929
# 2024-03-13    0.997927
# 2024-03-14    0.997927
# 2024-03-15    0.997927
# 2024-03-16    0.997927
# 2024-03-17    0.997927
# 2024-03-18    0.997927
# 2024-03-19    0.997927
# 2024-03-20    0.997927
# 2024-03-21    0.997927
# 2024-03-22    0.997927
# 2024-03-23    0.997927
# 2024-03-24    0.997927
# 2024-03-25    0.997927
# 2024-03-26    0.997927
# 2024-03-27    0.997927
# 2024-03-28    0.997927
# 2024-03-29    0.997927
# 2024-03-30    0.997927
# 2024-03-31    0.997927
# 2024-04-01    0.997927
# 2024-04-02    0.997927
# 2024-04-03    0.997927
# 2024-04-04    0.997927
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600123), 2024-03-11    1.116341
# 2024-03-12    0.986149
# 2024-03-13    1.001332
# 2024-03-14    0.999562
# 2024-03-15    0.999768
# 2024-03-16    0.999744
# 2024-03-17    0.999747
# 2024-03-18    0.999747
# 2024-03-19    0.999747
# 2024-03-20    0.999747
# 2024-03-21    0.999747
# 2024-03-22    0.999747
# 2024-03-23    0.999747
# 2024-03-24    0.999747
# 2024-03-25    0.999747
# 2024-03-26    0.999747
# 2024-03-27    0.999747
# 2024-03-28    0.999747
# 2024-03-29    0.999747
# 2024-03-30    0.999747
# 2024-03-31    0.999747
# 2024-04-01    0.999747
# 2024-04-02    0.999747
# 2024-04-03    0.999747
# 2024-04-04    0.999747
# 2024-04-05    0.999747
# 2024-04-06    0.999747
# 2024-04-07    0.999747
# 2024-04-08    0.999747
# 2024-04-09    0.999747
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600124), 2024-03-12    0.712041
# 2024-03-13    1.043614
# 2024-03-14    0.995563
# 2024-03-15    1.002526
# 2024-03-16    1.001517
# 2024-03-17    1.001663
# 2024-03-18    1.001642
# 2024-03-19    1.001645
# 2024-03-20    1.001645
# 2024-03-21    1.001645
# 2024-03-22    1.001645
# 2024-03-23    1.001645
# 2024-03-24    1.001645
# 2024-03-25    1.001645
# 2024-03-26    1.001645
# 2024-03-27    1.001645
# 2024-03-28    1.001645
# 2024-03-29    1.001645
# 2024-03-30    1.001645
# 2024-03-31    1.001645
# 2024-04-01    1.001645
# 2024-04-02    1.001645
# 2024-04-03    1.001645
# 2024-04-04    1.001645
# 2024-04-05    1.001645
# 2024-04-06    1.001645
# 2024-04-07    1.001645
# 2024-04-08    1.001645
# 2024-04-09    1.001645
# 2024-04-10    1.001645
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600125), 2024-03-06   -1.194675
# 2024-03-07    1.359264
# 2024-03-08    0.956501
# 2024-03-09    1.020018
# 2024-03-10    1.010001
# 2024-03-11    1.011581
# 2024-03-12    1.011332
# 2024-03-13    1.011371
# 2024-03-14    1.011365
# 2024-03-15    1.011366
# 2024-03-16    1.011366
# 2024-03-17    1.011366
# 2024-03-18    1.011366
# 2024-03-19    1.011366
# 2024-03-20    1.011366
# 2024-03-21    1.011366
# 2024-03-22    1.011366
# 2024-03-23    1.011366
# 2024-03-24    1.011366
# 2024-03-25    1.011366
# 2024-03-26    1.011366
# 2024-03-27    1.011366
# 2024-03-28    1.011366
# 2024-03-29    1.011366
# 2024-03-30    1.011366
# 2024-03-31    1.011366
# 2024-04-01    1.011366
# 2024-04-02    1.011366
# 2024-04-03    1.011366
# 2024-04-04    1.011366
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600126), 2024-03-05    1.163690
# 2024-03-06    0.983638
# 2024-03-07    1.011496
# 2024-03-08    1.007186
# 2024-03-09    1.007853
# 2024-03-10    1.007750
# 2024-03-11    1.007766
# 2024-03-12    1.007763
# 2024-03-13    1.007763
# 2024-03-14    1.007763
# 2024-03-15    1.007763
# 2024-03-16    1.007763
# 2024-03-17    1.007763
# 2024-03-18    1.007763
# 2024-03-19    1.007763
# 2024-03-20    1.007763
# 2024-03-21    1.007763
# 2024-03-22    1.007763
# 2024-03-23    1.007763
# 2024-03-24    1.007763
# 2024-03-25    1.007763
# 2024-03-26    1.007763
# 2024-03-27    1.007763
# 2024-03-28    1.007763
# 2024-03-29    1.007763
# 2024-03-30    1.007763
# 2024-03-31    1.007763
# 2024-04-01    1.007763
# 2024-04-02    1.007763
# 2024-04-03    1.007763
# Freq: D, Name: predicted_mean, dtype: float64), (np.int64(600127), 2024-03-19    1.159357
# 2024-03-20    0.976896
# 2024-03-21    1.005612
# 2024-03-22    1.001092
# 2024-03-23    1.001803
# 2024-03-24    1.001691
# 2024-03-25    1.001709
# 2024-03-26    1.001706
# 2024-03-27    1.001707
# 2024-03-28    1.001707
# 2024-03-29    1.001707
# 2024-03-30    1.001707
# 2024-03-31    1.001707
# 2024-04-01    1.001707
# 2024-04-02    1.001707
# 2024-04-03    1.001707
# 2024-04-04    1.001707
# 2024-04-05    1.001707
# 2024-04-06    1.001707
# 2024-04-07    1.001707
# 2024-04-08    1.001707
# 2024-04-09    1.001707
# 2024-04-10    1.001707
# 2024-04-11    1.001707
# 2024-04-12    1.001707
# 2024-04-13    1.001707
# 2024-04-14    1.001707
# 2024-04-15    1.001707
# 2024-04-16    1.001707
# 2024-04-17    1.001707
# Freq: D, Name: predicted_mean, dtype: float64)])

# %%
print(asset_forecasts[600100])
# Out:
# 2024-03-03    1.155839
# 2024-03-04    0.982155
# 2024-03-05    1.008254
# 2024-03-06    1.004332
# 2024-03-07    1.004922
# 2024-03-08    1.004833
# 2024-03-09    1.004847
# 2024-03-10    1.004845
# 2024-03-11    1.004845
# 2024-03-12    1.004845
# 2024-03-13    1.004845
# 2024-03-14    1.004845
# 2024-03-15    1.004845
# 2024-03-16    1.004845
# 2024-03-17    1.004845
# 2024-03-18    1.004845
# 2024-03-19    1.004845
# 2024-03-20    1.004845
# 2024-03-21    1.004845
# 2024-03-22    1.004845
# 2024-03-23    1.004845
# 2024-03-24    1.004845
# 2024-03-25    1.004845
# 2024-03-26    1.004845
# 2024-03-27    1.004845
# 2024-03-28    1.004845
# 2024-03-29    1.004845
# 2024-03-30    1.004845
# 2024-03-31    1.004845
# 2024-04-01    1.004845
# Freq: D, Name: predicted_mean, dtype: float64

# %% [markdown]
# ### Saving all asset residual data in a table

# %% [markdown]
# ## 🔴 NOTE
# - `residual value` = `Actual Annual_load_cost_per_month` - `predicted Annual_load_cost_per_month` <br>
# of each train data of `288` historic data
# - `residual value should be as close to zero as possible`

# %%
# Combine all residuals into one DataFrame
residuals_combined_df = pd.concat(all_residuals, ignore_index=True)

# Optional: sort and format
residuals_combined_df = residuals_combined_df[['Asset_Number', 'Incident_Date', 'residual_value']]

# %%
# Create the folder if it doesn't exist
os.makedirs("3_3_service_now_sarima_residuals_data", exist_ok=True)

# Save the Excel file inside the folder
residuals_combined_df.to_csv("3_3_service_now_sarima_residuals_data/3_3_service_now_sarima_residuals_data.csv", index=False)

# %%
# spark_df = spark.createDataFrame(residuals_combined_df)
# spark_df.write.mode("overwrite").saveAsTable("sd_bdc_demo.sarima_time_series_forecasting.3_3_service_now_sarima_residuals_data")

# %% [markdown]
# ### Saving all asset ACF data in a table

# %% [markdown]
# ## 🔴 NOTE
# - `Lag` = How far back you are looking in time (e.g., 1 month ago, 2 months ago, etc.)
# - `Autocorrelation` = How strongly the series is correlated with its own past values
# - `ACF should be as close to zero as possible (except at lag 0)`
#
# ## 📌 Guidelines to choose `nlags`
# | Scenario                       | Suggested `nlags`                   |
# | ------------------------------ | ----------------------------------- |
# | Short-term trend check         | 10–20                               |
# | Monthly data with seasonality  | ≥ 12 (check for 12-month patterns)  |
# | Quarterly data                 | ≥ 4 or 8                            |
# | Long series (e.g., 300 points) | Up to 40–50 or more                 |
# | Residual analysis              | 12–20 (slightly > forecast horizon) |
#
# ## ✅ Interpretation-1
# | Lag (k) | Meaning                                                           | Expected ACF Value                              |
# | ------- | ----------------------------------------------------------------- | ----------------------------------------------- |
# | 0       | Correlation of series with itself                                 | Always 1                                        |
# | 1       | Correlation with value 1 step before (e.g., 1 month ago)          | High if trend/seasonality exists, else low      |
# | 2       | Correlation with value 2 steps before                             | Usually lower than lag 1 unless there's pattern |
# | ...     | ...                                                               | Decreasing or oscillating depending on data     |
# | 12      | Monthly seasonality — high ACF if pattern repeats every 12 months | High if strong seasonality                      |
# | ≥ 13    | Less meaningful unless long-term memory or seasonality persists   | Usually low                                     |
#
# ## ✅ Interpretation-2
# | Lag | Expected ACF                                            |
# | --- | ------------------------------------------------------- |
# | 0   | 1 (always)                                              |
# | ≥1  | **Close to 0** — means model has captured all structure |

# %%
residuals_df = pd.concat(all_residuals).reset_index(drop=True)

# %%
from statsmodels.tsa.stattools import acf

acf_rows = []

for asset_id in residuals_df['Asset_Number'].unique():
    asset_resid = residuals_df[residuals_df['Asset_Number'] == asset_id]
    asset_resid_sorted = asset_resid.sort_values('Incident_Date')
    acf_values = acf(asset_resid_sorted['residual_value'], nlags=20)

    for lag, val in enumerate(acf_values):
        acf_rows.append({
            'Asset_Number': asset_id,
            'Lag': lag,
            'ACF_Value': round(val, 4)
        })

acf_df = pd.DataFrame(acf_rows)

# %%
# Create the folder if it doesn't exist
os.makedirs("3_4_service_now_sarima_acf_data", exist_ok=True)

# Save the Excel file inside the folder
acf_df.to_csv("3_4_service_now_sarima_acf_data/3_4_service_now_sarima_acf_data.csv", index=False)

# %%
# spark_df = spark.createDataFrame(acf_df)
# spark_df.write.mode("overwrite").saveAsTable("sd_bdc_demo.sarima_time_series_forecasting.3_4_service_now_sarima_acf_data")

# %% [markdown]
# ### Metrics for each asset

# %%
print(f"Asset 600100 Metrics: {asset_metrics[600100]}")
# Out:
# Asset 600100 Metrics: {'AIC': np.float64(4617.78190233272), 'MAPE': 0.509269131563291, 'RMSE': np.float64(2.44497116373238), 'ARIMA_order': {'trend': 0, 'exog': 0, 'ar': 1, 'ma': 1, 'seasonal_ar': 0, 'seasonal_ma': 0, 'reduced_ar': 1, 'reduced_ma': 1, 'exog_variance': 0, 'measurement_variance': 0, 'variance': 1}, 'residuals':      Incident_Date  residual_value
# 0       2021-04-08        1.000000
# 1       2021-04-09        5.075133
# 2       2021-04-10       -5.248645
# 3       2021-04-11       -3.525927
# 4       2021-04-12       -2.350620
# ...            ...             ...
# 1055    2024-02-27       -1.151500
# 1056    2024-02-28        7.849591
# 1057    2024-02-29        0.194556
# 1058    2024-03-01       -1.158026
# 1059    2024-03-02       -1.156932
#
# [1060 rows x 2 columns]}

# %% [markdown]
# ### Saving all asset metrics in a table

# %%
rows = []

for asset_id, metrics in asset_metrics.items():
    ar = metrics['ARIMA_order'].get('ar', '?')
    d = 1 # assumed
    ma = metrics['ARIMA_order'].get('ma', '?')

    seasonal_ar = metrics['ARIMA_order'].get('seasonal_ar', '?')
    seasonal_d = 0  # assumed seasonal differencing
    seasonal_ma = metrics['ARIMA_order'].get('seasonal_ma', '?')
    s = 0 # assumed 
    
    rows.append({
        'Asset_ID': asset_id,
        'AIC_unitless': round(float(metrics['AIC']), 2),
        'MAPE_%': round(float(metrics['MAPE']) * 100, 2),
        'RMSE_$': round(float(metrics['RMSE']), 2),
        'ARIMA_order': f"({ar},{d},{ma})",
        'Seasonal_order': f"({seasonal_ar},{seasonal_d},{seasonal_ma},{s})"
    })

metrics_df_clean = pd.DataFrame(rows)

# %%
# Create the folder if it doesn't exist
os.makedirs("3_1_service_now_sarima_metrics_data", exist_ok=True)

# Save the Excel file inside the folder
metrics_df_clean.to_csv("3_1_service_now_sarima_metrics_data/3_1_service_now_sarima_metrics_data.csv", index=False)

# %%
# spark_df = spark.createDataFrame(metrics_df_clean)
# spark_df.write.mode("overwrite").saveAsTable("sd_bdc_demo.sarima_time_series_forecasting.3_1_service_now_sarima_metrics_data")

# %% [markdown]
# ## Plot Prediction of Single asset

# %%
import matplotlib.pyplot as plt

asset_id = 600100
asset_df = asset_dfs[asset_id].copy()
asset_df['Incident_Date'] = pd.to_datetime(asset_df['Incident_Date'])
asset_df.set_index('Incident_Date', inplace=True)

forecast = asset_forecasts[asset_id]

plt.figure(figsize=(10, 4))
plt.plot(asset_df['Gap_Days'], label='Actual')
plt.plot(forecast, label='Forecast', linestyle='--')
plt.title(f'Asset {asset_id} Forecast')
plt.legend()
plt.show()

# %% [markdown]
# ## Saving the Predicted Data

# %%
all_forecasts = []

for asset_id, forecast_series in asset_forecasts.items():
    for date, cost in forecast_series.items():
        all_forecasts.append({
            'Asset_ID': asset_id,
            'Incident_Date': date,
            'Gap_Days': round(cost, 0)
        })

forecast_df = pd.DataFrame(all_forecasts)

# Step 4: Sort and reset index (optional but clean)
forecast_df = forecast_df.sort_values(['Asset_ID', 'Incident_Date']).reset_index(drop=True)

# %%
print(forecast_df.head())
# Out:
#    Asset_ID Incident_Date  Gap_Days
# 0    100080    2024-03-10       1.0
# 1    100080    2024-03-11       1.0
# 2    100080    2024-03-12       1.0
# 3    100080    2024-03-13       1.0
# 4    100080    2024-03-14       1.0

# %%
forecast_df['Incident_Date'] = pd.to_datetime(forecast_df['Incident_Date'])

# %% [markdown]
# ## Export Updated Excel

# %%
# Create the folder if it doesn't exist
os.makedirs("3_2_service_now_sarima_forecasted_data", exist_ok=True)

# Save the Excel file inside the folder
forecast_df.to_csv("3_2_service_now_sarima_forecasted_data/3_2_service_now_sarima_forecasted_data.csv", index=False)

# %%
# spark_df = spark.createDataFrame(forecast_df)
# spark_df.write.mode("overwrite").saveAsTable("sd_bdc_demo.sarima_time_series_forecasting.3_2_service_now_sarima_forecasted_data")
